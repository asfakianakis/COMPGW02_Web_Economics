# %% [markdown]
# # Abstract

# %% [markdown]
# This notebook uses all the implemented pCTR and basebid models along with the different strategies and uses a function to find the best-performing individual model on the validation set.

# %% [markdown]
# # Import data

# %%
import pandas as pd
import numpy as np
from functools import reduce
import matplotlib.pyplot as plt
import seaborn as sns
import time

# %matplotlib inline
pd.set_option('display.max_columns', None)
pd.options.mode.chained_assignment = None  # To ignore SettingWithCopyWarning warning

# %%
train = pd.read_csv("train.csv")
validation = pd.read_csv("validation.csv")

# %%
print(train.shape, validation.shape)
# Out:
# (2430981, 25) (303925, 25)

# %% [markdown]
# # Import Predictions

# %%
lr_preds = pd.read_csv("Prediction_csv/lr_pCTR.csv", index_col  = "Unnamed: 0")
rf_preds = pd.read_csv("Prediction_csv/rf_pCTR.csv", index_col  = "Unnamed: 0")
xgb_preds = pd.read_csv("Prediction_csv/xgb_pCTR.csv", index_col  = "Unnamed: 0")
dwane_preds = pd.read_csv("Prediction_csv/click_predictions_narrow.csv")
lasso_preds = pd.read_csv("Prediction_csv/lasso_basebid.csv", index_col  = "Unnamed: 0")
ridge_preds = pd.read_csv("Prediction_csv/ridge_basebid.csv", index_col  = "Unnamed: 0")
elasticnet_preds = pd.read_csv("Prediction_csv/elasticnet_basebid.csv", index_col  = "Unnamed: 0")
rfg_preds = pd.read_csv("Prediction_csv/rfg_basebid.csv", index_col  = "Unnamed: 0")
xgbr_preds = pd.read_csv("Prediction_csv/xgb_basebid.csv", index_col  = "Unnamed: 0")

# %%
# Ensemble model
ensemble_prob =xgb_preds["click_proba"]*dwane_preds["click_proba"]
ensemble_pCTR_preds = pd.DataFrame(columns = ["bidid", "click_proba"], 
                                   data = list(zip(validation["bidid"], ensemble_prob)))

ensemble_basebid = 0.2* (lasso_preds["predicted_payprice"] + ridge_preds["predicted_payprice"] + elasticnet_preds["predicted_payprice"] +\
                  rfg_preds["predicted_payprice"] + xgbr_preds["predicted_payprice"])
ensemble_basebid_preds = pd.DataFrame(columns = ["bidid", "predicted_payprice"], 
                                   data = list(zip(validation["bidid"], ensemble_basebid)))

# %%
ensemble_pCTR_preds.head()
# Out:
#                                       bidid  click_proba
# 0  bbcb813b6166538503d8b33a5602d7d72f6019dc          0.0
# 1  5a07316c49477cb5d9b4d5aa39c27d6c3be7f92d          0.0
# 2  f6ece71dae81d6b16bfb24ad6dd5611472d4c673          0.0
# 3  b4d5c57c9b38ff5a12954fa01e11931b4e6bfbbb          0.0
# 4  0899bf144249458ea9c89188473694bf44c7ca15          0.0

# %%
ensemble_basebid_preds.head()
# Out:
#                                       bidid  predicted_payprice
# 0  bbcb813b6166538503d8b33a5602d7d72f6019dc           67.205068
# 1  5a07316c49477cb5d9b4d5aa39c27d6c3be7f92d           77.476141
# 2  f6ece71dae81d6b16bfb24ad6dd5611472d4c673           78.094520
# 3  b4d5c57c9b38ff5a12954fa01e11931b4e6bfbbb           45.960159
# 4  0899bf144249458ea9c89188473694bf44c7ca15           49.426684

# %%
base_bid = train.loc[ train["click"] == 1, "payprice"].mean()
avgCTR = train["click"].sum()*100/train.shape[0]

# %%
print("Base bid: {}, avgCTR: {}, ratio: {}".format(base_bid, avgCTR, base_bid/avgCTR))
# Out:
# Base bid: 105.46402677077523, avgCTR: 0.07375623256619447, ratio: 1429.899862037066

# %% [markdown]
# # Strategies

# %%
def Strategy1(sub_pCTR, sub_basebid):
    
    #avgCTR = train["click"].sum()*100/train.shape[0]
    avgCTR = sub_pCTR["click_proba"].mean()
    base_bid = train.loc[ train["click"] == 1, "payprice"].mean()
    bidprice = (sub_pCTR["click_proba"] * base_bid) / avgCTR
    return bidprice

def Strategy2(sub_pCTR, sub_basebid):
    
    #avgCTR = 0.5
    avgCTR = sub_pCTR["click_proba"].mean()
    bidprice = (sub_pCTR["click_proba"] * sub_basebid["predicted_payprice"]) / avgCTR
    return bidprice

def Strategy3(sub_pCTR, sub_basebid):
    
    #avgCTR = 0.5
    avgCTR = sub_pCTR["click_proba"].mean()
    sub_pCTR_ = sub_pCTR.copy()
    sub_pCTR_["click_proba"] = sub_pCTR_["click_proba"].map(lambda x: 0 if x <0.3 else np.exp(x))
    bidprice = (sub_pCTR_["click_proba"] * sub_basebid["predicted_payprice"]) / avgCTR
    return bidprice

def Strategy4(sub_pCTR, sub_basebid):
    
    #avgCTR = 0.5
    avgCTR = sub_pCTR["click_proba"].mean()
    sub_pCTR_ = sub_pCTR.copy()
    sub_pCTR_["click_proba"] = (sub_pCTR_["click_proba"] + 0.5)**2 - 0.5
    sub_pCTR_.loc[sub_pCTR_["click_proba"] < 0, "click_proba"] = 0
    bidprice = (sub_pCTR_["click_proba"] * sub_basebid["predicted_payprice"]) / avgCTR
    return bidprice

# %% [markdown]
# # Evaluate Results

# %%
budget = 6250*1000

def ValidationDataFrame(submission_pCTR, submission_basebid, strategy):
    
    validation_check = validation[["bidid", "click", "bidprice", "payprice"]]
    validation_check["click_proba"] = submission_pCTR["click_proba"]
    validation_check["basebid_predicted"] = submission_basebid["predicted_payprice"]
    validation_check["bidprice_predicted"] = strategy(submission_pCTR, submission_basebid)
    
    return validation_check


def ValidateStrategy(df):
    
    impressions = 0
    clicks = 0
    cost = 0
    auctions_participated = 0
    balance = budget
    
    for row in df.iterrows():
        
        if cost < budget:
            
            auctions_participated+=1
            
            if (row[1]["bidprice_predicted"] >= row[1]["payprice"]):
                
                if (balance > row[1]["bidprice_predicted"]):
                    
                    impressions+=1
                    clicks+=row[1]["click"]
                    cost+=row[1]["payprice"]
                    balance-=row[1]["payprice"]
                else:
                    pass
    
        else:
            break
    
    # Metrics
    ctr = clicks*100/impressions
    cpm = cost/impressions
    cpc = cost/clicks/1000
    
    print("Strategy statistics:")
    print("Auctions participated: {} | Impressions: {} | Clicks: {} | Cost: {} | CTR: {} | CPM: {} | CPC: {}".format(auctions_participated, \
                                                                                                                     impressions, clicks, cost,\
                                                                                                                     ctr, cpm, cpc))
    print("\n")
            
    return impressions, clicks, cost, auctions_participated, ctr, cpm, cpc

# def StrategyResults(impressions, clicks, cost):
#     ctr = clicks*100/impressions
#     spend = cost
#     cpm = cost/(impressions*1000)
#     if clicks > 0:
#         cpc = cost/clicks
#     else:
#         cpc = np.inf
        
#     print("Strategy results")
#     print("CTR: {} | Clicks: {} | Spend: {} | CPM: {} | CPC: {}".format(ctr, clicks, spend, cpm, cpc))
#     print("\n")
        
#     return ctr, clicks, spend, cpm, cpc

# %%
pCTR_preds = [ensemble_pCTR_preds, lr_preds, rf_preds, xgb_preds, dwane_preds]
basebid_preds = [ensemble_basebid_preds, lasso_preds, ridge_preds, elasticnet_preds, rfg_preds, xgbr_preds]
pCTR_model_names = ["Ensemble", "Logistic Regression", "Random Forest", "XGBoost", "Forest of RF"]
basebid_model_names = ["Ensemble", "Lasso", "Ridge", "Elastic Net", "Random Forest Regressor", "XGBoost Regressor"]
results = pd.DataFrame(columns = ["pCTR_model", "basebid_model", "Strategy", "Impressions", "Clicks", "Cost", "CTR", "CPM", "CPC"])
i=0
j=0
k=0

start = time.time()

for pCTR_pred in pCTR_preds:
    for basebid_pred in basebid_preds:
        
        # Strategy 1
        validation_check = ValidationDataFrame(pCTR_pred, basebid_pred, Strategy1)
        print("\033[1m pCTR model: {} \033[0m, \033[1m basebid model: {} \033[0m, \033[1m Strategy 1 \033[0m ".format(pCTR_model_names[i], basebid_model_names[j]))
        impressions, clicks, cost, auctions_participated, ctr, cpm, cpc = ValidateStrategy(validation_check)
        results.loc[k] = [pCTR_model_names[i], basebid_model_names[j], "Strategy1", impressions, clicks, cost, ctr, cpm, cpc]
        k+=1
        
        # Strategy 2
        validation_check = ValidationDataFrame(pCTR_pred, basebid_pred, Strategy2)
        print("\033[1m pCTR model: {} \033[0m, \033[1m basebid model: {} \033[0m, \033[1m Strategy 2 \033[0m ".format(pCTR_model_names[i], basebid_model_names[j]))
        impressions, clicks, cost, auctions_participated, ctr, cpm, cpc = ValidateStrategy(validation_check)
        results.loc[k] = [pCTR_model_names[i], basebid_model_names[j], "Strategy2", impressions, clicks, cost, ctr, cpm, cpc]
        k+=1
        
        # Strategy 3
        validation_check = ValidationDataFrame(pCTR_pred, basebid_pred, Strategy3)
        print("\033[1m pCTR model: {} \033[0m, \033[1m basebid model: {} \033[0m, \033[1m Strategy 3 \033[0m ".format(pCTR_model_names[i], basebid_model_names[j]))
        impressions, clicks, cost, auctions_participated, ctr, cpm, cpc= ValidateStrategy(validation_check)
        results.loc[k] = [pCTR_model_names[i], basebid_model_names[j], "Strategy3", impressions, clicks, cost, ctr, cpm, cpc]
        k+=1
        
        # Strategy 4
        validation_check = ValidationDataFrame(pCTR_pred, basebid_pred, Strategy4)
        print("\033[1m pCTR model: {} \033[0m, \033[1m basebid model: {} \033[0m, \033[1m Strategy 4 \033[0m ".format(pCTR_model_names[i], basebid_model_names[j]))
        impressions, clicks, cost, auctions_participated, ctr, cpm, cpc= ValidateStrategy(validation_check)
        results.loc[k] = [pCTR_model_names[i], basebid_model_names[j], "Strategy4", impressions, clicks, cost, ctr, cpm, cpc]
        k+=1
        
        j+=1
        
        
    j=0    
    i+=1
    
end = time.time()
print("Total time: {} mins".format((end-start)/60))
# Out:
#  pCTR model: Ensemble ,  basebid model: Ensemble ,  Strategy 1
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 53628 | Clicks: 151 | Cost: 3945401 | CTR: 0.28156932945476243 | CPM: 73.56979562914896 | CPC: 26.12848344370861
#
#
#  pCTR model: Ensemble ,  basebid model: Ensemble ,  Strategy 2
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 49391 | Clicks: 146 | Cost: 3742856 | CTR: 0.2956004130307141 | CPM: 75.78012188455386 | CPC: 25.636
#
#
#  pCTR model: Ensemble ,  basebid model: Ensemble ,  Strategy 3
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 6004 | Clicks: 101 | Cost: 498730 | CTR: 1.6822118587608261 | CPM: 83.06628914057295 | CPC: 4.937920792079208
#
#
#  pCTR model: Ensemble ,  basebid model: Ensemble ,  Strategy 4
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 8921 | Clicks: 108 | Cost: 715533 | CTR: 1.2106266113664388 | CPM: 80.20771213989462 | CPC: 6.625305555555555
#
#
#  pCTR model: Ensemble ,  basebid model: Lasso ,  Strategy 1
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 53628 | Clicks: 151 | Cost: 3945401 | CTR: 0.28156932945476243 | CPM: 73.56979562914896 | CPC: 26.12848344370861
#
#
#  pCTR model: Ensemble ,  basebid model: Lasso ,  Strategy 2
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 49116 | Clicks: 144 | Cost: 3645206 | CTR: 0.2931834839970682 | CPM: 74.21626353937617 | CPC: 25.313930555555554
#
#
#  pCTR model: Ensemble ,  basebid model: Lasso ,  Strategy 3
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 6004 | Clicks: 101 | Cost: 498730 | CTR: 1.6822118587608261 | CPM: 83.06628914057295 | CPC: 4.937920792079208
#
#
#  pCTR model: Ensemble ,  basebid model: Lasso ,  Strategy 4
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 8894 | Clicks: 108 | Cost: 710609 | CTR: 1.2143017764785249 | CPM: 79.89757139644705 | CPC: 6.5797129629629625
#
#
#  pCTR model: Ensemble ,  basebid model: Ridge ,  Strategy 1
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 53628 | Clicks: 151 | Cost: 3945401 | CTR: 0.28156932945476243 | CPM: 73.56979562914896 | CPC: 26.12848344370861
#
#
#  pCTR model: Ensemble ,  basebid model: Ridge ,  Strategy 2
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 49314 | Clicks: 144 | Cost: 3719780 | CTR: 0.29200632680374744 | CPM: 75.43050654986413 | CPC: 25.831805555555555
#
#
#  pCTR model: Ensemble ,  basebid model: Ridge ,  Strategy 3
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 6003 | Clicks: 101 | Cost: 498710 | CTR: 1.6824920872896885 | CPM: 83.0767949358654 | CPC: 4.937722772277228
#
#
#  pCTR model: Ensemble ,  basebid model: Ridge ,  Strategy 4
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 8908 | Clicks: 109 | Cost: 714111 | CTR: 1.2236192186798382 | CPM: 80.16513246519982 | CPC: 6.551477064220184
#
#
#  pCTR model: Ensemble ,  basebid model: Elastic Net ,  Strategy 1
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 53628 | Clicks: 151 | Cost: 3945401 | CTR: 0.28156932945476243 | CPM: 73.56979562914896 | CPC: 26.12848344370861
#
#
#  pCTR model: Ensemble ,  basebid model: Elastic Net ,  Strategy 2
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 49120 | Clicks: 144 | Cost: 3672535 | CTR: 0.2931596091205212 | CPM: 74.76659201954398 | CPC: 25.50371527777778
#
#
#  pCTR model: Ensemble ,  basebid model: Elastic Net ,  Strategy 3
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 6004 | Clicks: 101 | Cost: 498730 | CTR: 1.6822118587608261 | CPM: 83.06628914057295 | CPC: 4.937920792079208
#
#
#  pCTR model: Ensemble ,  basebid model: Elastic Net ,  Strategy 4
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 8902 | Clicks: 109 | Cost: 712565 | CTR: 1.2244439451808582 | CPM: 80.04549539429341 | CPC: 6.537293577981652
#
#
#  pCTR model: Ensemble ,  basebid model: Random Forest Regressor ,  Strategy 1
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 53628 | Clicks: 151 | Cost: 3945401 | CTR: 0.28156932945476243 | CPM: 73.56979562914896 | CPC: 26.12848344370861
#
#
#  pCTR model: Ensemble ,  basebid model: Random Forest Regressor ,  Strategy 2
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 48798 | Clicks: 146 | Cost: 3772737 | CTR: 0.29919258986024017 | CPM: 77.31335300627075 | CPC: 25.840664383561645
#
#
#  pCTR model: Ensemble ,  basebid model: Random Forest Regressor ,  Strategy 3
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 6004 | Clicks: 101 | Cost: 498730 | CTR: 1.6822118587608261 | CPM: 83.06628914057295 | CPC: 4.937920792079208
#
#
#  pCTR model: Ensemble ,  basebid model: Random Forest Regressor ,  Strategy 4
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 8909 | Clicks: 108 | Cost: 715862 | CTR: 1.2122572679313055 | CPM: 80.35267706813335 | CPC: 6.6283518518518525
#
#
#  pCTR model: Ensemble ,  basebid model: XGBoost Regressor ,  Strategy 1
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 53628 | Clicks: 151 | Cost: 3945401 | CTR: 0.28156932945476243 | CPM: 73.56979562914896 | CPC: 26.12848344370861
#
#
#  pCTR model: Ensemble ,  basebid model: XGBoost Regressor ,  Strategy 2
# Strategy statistics:
# Auctions participated: 303925 | Impressions:
,  basebid model: Lasso ,  Strategy 3
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 59969 | Clicks: 157 | Cost: 5346476 | CTR: 0.2618019309976821 | CPM: 89.15399623138622 | CPC: 34.053987261146496
#
#
#  pCTR model: Forest of RF ,  basebid model: Lasso ,  Strategy 4
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 55294 | Clicks: 149 | Cost: 4664094 | CTR: 0.2694686584439541 | CPM: 84.35081564003328 | CPC: 31.302644295302013
#
#
#  pCTR model: Forest of RF ,  basebid model: Ridge ,  Strategy 1
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 76822 | Clicks: 160 | Cost: 5990518 | CTR: 0.2082736716044883 | CPM: 77.97919866704851 | CPC: 37.440737500000004
#
#
#  pCTR model: Forest of RF ,  basebid model: Ridge ,  Strategy 2
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 73498 | Clicks: 159 | Cost: 5767255 | CTR: 0.21633241720863153 | CPM: 78.46818961060166 | CPC: 36.272044025157236
#
#
#  pCTR model: Forest of RF ,  basebid model: Ridge ,  Strategy 3
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 59963 | Clicks: 157 | Cost: 5345680 | CTR: 0.2618281273451962 | CPM: 89.14964227940564 | CPC: 34.04891719745223
#
#
#  pCTR model: Forest of RF ,  basebid model: Ridge ,  Strategy 4
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 55585 | Clicks: 148 | Cost: 4712867 | CTR: 0.2662588827921202 | CPM: 84.78666906539534 | CPC: 31.843695945945946
#
#
#  pCTR model: Forest of RF ,  basebid model: Elastic Net ,  Strategy 1
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 76822 | Clicks: 160 | Cost: 5990518 | CTR: 0.2082736716044883 | CPM: 77.97919866704851 | CPC: 37.440737500000004
#
#
#  pCTR model: Forest of RF ,  basebid model: Elastic Net ,  Strategy 2
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 73385 | Clicks: 159 | Cost: 5724745 | CTR: 0.21666553110308645 | CPM: 78.00974313551816 | CPC: 36.0046855345912
#
#
#  pCTR model: Forest of RF ,  basebid model: Elastic Net ,  Strategy 3
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 59969 | Clicks: 157 | Cost: 5346476 | CTR: 0.2618019309976821 | CPM: 89.15399623138622 | CPC: 34.053987261146496
#
#
#  pCTR model: Forest of RF ,  basebid model: Elastic Net ,  Strategy 4
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 55268 | Clicks: 148 | Cost: 4672377 | CTR: 0.267786060649924 | CPM: 84.5403669392777 | CPC: 31.570114864864863
#
#
#  pCTR model: Forest of RF ,  basebid model: Random Forest Regressor ,  Strategy 1
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 76822 | Clicks: 160 | Cost: 5990518 | CTR: 0.2082736716044883 | CPM: 77.97919866704851 | CPC: 37.440737500000004
#
#
#  pCTR model: Forest of RF ,  basebid model: Random Forest Regressor ,  Strategy 2
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 72696 | Clicks: 160 | Cost: 5788614 | CTR: 0.22009464069549906 | CPM: 79.62768240343348 | CPC: 36.1788375
#
#
#  pCTR model: Forest of RF ,  basebid model: Random Forest Regressor ,  Strategy 3
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 59948 | Clicks: 157 | Cost: 5341836 | CTR: 0.26189364115566827 | CPM: 89.10782678321212 | CPC: 34.02443312101911
#
#
#  pCTR model: Forest of RF ,  basebid model: Random Forest Regressor ,  Strategy 4
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 55364 | Clicks: 151 | Cost: 4721042 | CTR: 0.27274040892999063 | CPM: 85.27277653348746 | CPC: 31.26517880794702
#
#
#  pCTR model: Forest of RF ,  basebid model: XGBoost Regressor ,  Strategy 1
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 76822 | Clicks: 160 | Cost: 5990518 | CTR: 0.2082736716044883 | CPM: 77.97919866704851 | CPC: 37.440737500000004
#
#
#  pCTR model: Forest of RF ,  basebid model: XGBoost Regressor ,  Strategy 2
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 72795 | Clicks: 158 | Cost: 5808658 | CTR: 0.21704787416718183 | CPM: 79.79473864963254 | CPC: 36.7636582278481
#
#
#  pCTR model: Forest of RF ,  basebid model: XGBoost Regressor ,  Strategy 3
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 59888 | Clicks: 157 | Cost: 5339690 | CTR: 0.26215602457921455 | CPM: 89.16126769970612 | CPC: 34.0107643312102
#
#
#  pCTR model: Forest of RF ,  basebid model: XGBoost Regressor ,  Strategy 4
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 55325 | Clicks: 148 | Cost: 4724848 | CTR: 0.2675101671938545 | CPM: 85.40168097605061 | CPC: 31.92464864864865
#
#
# Total time: 50.37581826448441 mins

# %%
#results["CPM"] = results["CPM"]/1000
# results["CPC"] = results["CPC"]/1000

# %%
results.to_csv("ValidationSet_Evaluation_Results.csv")

# %%
pd.options.display.max_rows = results.shape[0]
results.sort_values(by = ["Clicks", "CTR"], ascending = False)
# Out:
#               pCTR_model            basebid_model   Strategy Impressions  \
# 113         Forest of RF  Random Forest Regressor  Strategy2       72696
# 96          Forest of RF                 Ensemble  Strategy1       76822
# 100         Forest of RF                    Lasso  Strategy1       76822
# 104         Forest of RF                    Ridge  Strategy1       76822
# 108         Forest of RF              Elastic Net  Strategy1       76822
# 112         Forest of RF  Random Forest Regressor  Strategy1       76822
# 116         Forest of RF        XGBoost Regressor  Strategy1       76822
# 89               XGBoost  Random Forest Regressor  Strategy2       99688
# 73               XGBoost                 Ensemble  Strategy2      103711
# 85               XGBoost              Elastic Net  Strategy2      104562
# 77               XGBoost                    Lasso  Strategy2      104900
# 109         Forest of RF              Elastic Net  Strategy2       73385
# 105         Forest of RF                    Ridge  Strategy2       73498
# 97          Forest of RF                 Ensemble  Strategy2       73746
# 117         Forest of RF        XGBoost Regressor  Strategy2       72795
# 93               XGBoost        XGBoost Regressor  Strategy2       99517
# 118         Forest of RF        XGBoost Regressor  Strategy3       59888
# 114         Forest of RF  Random Forest Regressor  Strategy3       59948
# 106         Forest of RF                    Ridge  Strategy3       59963
# 98          Forest of RF                 Ensemble  Strategy3       59969
# 102         Forest of RF                    Lasso  Strategy3       59969
# 110         Forest of RF              Elastic Net  Strategy3       59969
# 101         Forest of RF                    Lasso  Strategy2       73482
# 81               XGBoost                    Ridge  Strategy2      102969
# 0               Ensemble                 Ensemble  Strategy1       53628
# 4               Ensemble                    Lasso  Strategy1       53628
# 8               Ensemble                    Ridge  Strategy1       53628
# 12              Ensemble              Elastic Net  Strategy1       53628
# 16              Ensemble  Random Forest Regressor  Strategy1       53628
# 20              Ensemble        XGBoost Regressor  Strategy1       53628
# 115         Forest of RF  Random Forest Regressor  Strategy4       55364
# 99          Forest of RF                 Ensemble  Strategy4       55523
# 103         Forest of RF                    Lasso  Strategy4       55294
# 111         Forest of RF              Elastic Net  Strategy4       55268
# 119         Forest of RF        XGBoost Regressor  Strategy4       55325
# 107         Forest of RF                    Ridge  Strategy4       55585
# 17              Ensemble  Random Forest Regressor  Strategy2       48798
# 1               Ensemble                 Ensemble  Strategy2       49391
# 21              Ensemble        XGBoost Regressor  Strategy2       49010
# 5               Ensemble                    Lasso  Strategy2       49116
# 13              Ensemble              Elastic Net  Strategy2       49120
# 9               Ensemble                    Ridge  Strategy2       49314
# 72               XGBoost                 Ensemble  Strategy1      115614
# 76               XGBoost                    Lasso  Strategy1      115614
# 80               XGBoost                    Ridge  Strategy1      115614
# 84               XGBoost              Elastic Net  Strategy1      115614
# 88               XGBoost  Random Forest Regressor  Strategy1      115614
# 92               XGBoost        XGBoost Regressor  Strategy1      115614
# 57         Random Forest                    Ridge  Strategy2      122979
# 49         Random Forest                 Ensemble  Strategy2      122352
# 61         Random Forest              Elastic Net  Strategy2      126848
# 53         Random Forest                    Lasso  Strategy2      127526
# 65         Random Forest  Random Forest Regressor  Strategy2      114862
# 69         Random Forest        XGBoost Regressor  Strategy2      113964
# 31   Logistic Regression                    Lasso  Strategy4      152951
# 63         Random Forest              Elastic Net  Strategy4       16663
# 67         Random Forest  Random Forest Regressor  Strategy4       16771
# 51         Random Forest                 Ensemble  Strategy4       16872
# 71         Random Forest        XGBoost Regressor  Strategy4       16858
# 35   Logistic Regression                    Ridge  Strategy4      148521
# 59         Random Forest                    Ridge  Strategy4       16621
# 58         Random Forest                    Ridge  Strategy3       14118
# 70         Random Forest        XGBoost Regressor  Strategy3       14126
# 66         Random Forest  Random Forest Regressor  Strategy3       14130
# 50         Random Forest                 Ensemble  Strategy3       14132
# 54         Random Forest                    Lasso  Strategy3       14132
# 62         Random Forest              Elastic Net  Strategy3       14132
# 55         Random Forest                    Lasso  Strategy4       16702
# 39   Logistic Regression              Elastic Net  Strategy4      153168
# 27   Logistic Regression                 Ensemble  Strategy4      147914
# 48         Random Forest                 Ensemble  Strategy1      122112
# 52         Random Forest                    Lasso  Strategy1      122112
# 56         Random Forest                    Ridge  Strategy1      122112
# 60         Random Forest              Elastic Net  Strategy1      122112
# 64         Random Forest  Random Forest Regressor  Strategy1      122112
# 68         Random Forest        XGBoost Regressor  Strategy1      122112
# 15              Ensemble              Elastic Net  Strategy4        8902
# 11              Ensemble                    Ridge  Strategy4        8908
# 43   Logistic Regression  Random Forest Regressor  Strategy4      137938
# 7               Ensemble                    Lasso  Strategy4        8894
# 19              Ensemble  Random Forest Regressor  Strategy4        8909
# 23              Ensemble        XGBoost Regressor  Strategy4        8915
# 3               Ensemble                 Ensemble  Strategy4        8921
# 79               XGBoost                    Lasso  Strategy4        9947
# 87               XGBoost              Elastic Net  Strategy4        9954
# 95               XGBoost        XGBoost Regressor  Strategy4       10008
# 75               XGBoost                 Ensemble  Strategy4       10017
# 91               XGBoost  Random Forest Regressor  Strategy4       10026
# 83               XGBoost                    Ridge  Strategy4        9954
# 47   Logistic Regression        XGBoost Regressor  Strategy4      136678
# 22              Ensemble        XGBoost Regressor  Strategy3        6002
# 10              Ensemble                    Ridge  Strategy3        6003
# 2               Ensemble                 Ensemble  Strategy3        6004
# 6               Ensemble                    Lasso  Strategy3        6004
# 14              Ensemble              Elastic Net  Strategy3        6004
# 18              Ensemble  Random Forest Regressor  Strategy3        6004
# 94               XGBoost        XGBoost Regressor  Strategy3        6894
# 82               XGBoost                    Ridge  Strategy3        6896
# 74               XGBoost                 Ensemble  Strategy3        6897
# 78               XGBoost                    Lasso  Strategy3        6897
# 86               XGBoost              Elastic Net  Strategy3        6897
# 90               XGBoost  Random Forest Regressor  Strategy3        6897
# 25   Logistic Regression                 Ensemble  Strategy2      137137
# 41   Logistic Regression  Random Forest Regressor  Strategy2      127586
# 29   Logistic Regression                    Lasso  Strategy2      142482
# 33   Logistic Regression                    Ridge  Strategy2      138439
# 37   Logistic Regression              Elastic Net  Strategy2      142566
# 45   Logistic Regression        XGBoost Regressor  Strategy2      125689
# 24   Logistic Regression                 Ensemble  Strategy1      122870
# 28   Logistic Regression                    Lasso  Strategy1      122870
# 32   Logistic Regression                    Ridge  Strategy1      122870
# 36   Logistic Regression              Elastic Net  Strategy1      122870
# 40   Logistic Regression  Random Forest Regressor  Strategy1      122870
# 44   Logistic Regression        XGBoost Regressor  Strategy1      122870
# 34   Logistic Regression                    Ridge  Strategy3       82248
# 46   Logistic Regression        XGBoost Regressor  Strategy3       82413
# 42   Logistic Regression  Random Forest Regressor  Strategy3       82819
# 30   Logistic Regression                    Lasso  Strategy3       82376
