# %%
import pandas as pd
import numpy as np
from functools import reduce
import matplotlib.pyplot as plt
import seaborn as sns
import time

# %matplotlib inline
pd.set_option('display.max_columns', None)
pd.options.mode.chained_assignment = None  # To ignore SettingWithCopyWarning warning

# %% [markdown]
# # Import data

# %%
train = pd.read_csv("train.csv")
validation = pd.read_csv("validation.csv")

# %%
print(train.shape, validation.shape)
# Out:
# (2430981, 25) (303925, 25)

# %% [markdown]
# # Import Predictions

# %%
lr_preds = pd.read_csv("Prediction_csv/lr_pCTR.csv", index_col  = "Unnamed: 0")
rf_preds = pd.read_csv("Prediction_csv/rf_pCTR.csv", index_col  = "Unnamed: 0")
xgb_preds = pd.read_csv("Prediction_csv/xgb_pCTR.csv", index_col  = "Unnamed: 0")
dwane_preds = pd.read_csv("Prediction_csv/click_predictions_narrow.csv")
lasso_preds = pd.read_csv("Prediction_csv/lasso_basebid.csv", index_col  = "Unnamed: 0")
ridge_preds = pd.read_csv("Prediction_csv/ridge_basebid.csv", index_col  = "Unnamed: 0")
elasticnet_preds = pd.read_csv("Prediction_csv/elasticnet_basebid.csv", index_col  = "Unnamed: 0")
rfg_preds = pd.read_csv("Prediction_csv/rfg_basebid.csv", index_col  = "Unnamed: 0")
xgbr_preds = pd.read_csv("Prediction_csv/xgb_basebid.csv", index_col  = "Unnamed: 0")

# %%
# Ensemble model
ensemble_prob = 0.25*lr_preds["click_proba"] + 0.25*rf_preds["click_proba"] + \
                0.25*xgb_preds["click_proba"] + 0.25*dwane_preds["click_proba"]
ensemble_pCTR_preds = pd.DataFrame(columns = ["bidid", "click_proba"], 
                                   data = list(zip(validation["bidid"], ensemble_prob)))

ensemble_basebid = 0.2* (lasso_preds["predicted_payprice"] + ridge_preds["predicted_payprice"] + elasticnet_preds["predicted_payprice"] +\
                  rfg_preds["predicted_payprice"] + xgbr_preds["predicted_payprice"])
ensemble_basebid_preds = pd.DataFrame(columns = ["bidid", "predicted_payprice"], 
                                   data = list(zip(validation["bidid"], ensemble_basebid)))

# %%
ensemble_pCTR_preds.head()
# Out:
#                                       bidid  click_proba
# 0  bbcb813b6166538503d8b33a5602d7d72f6019dc     0.149347
# 1  5a07316c49477cb5d9b4d5aa39c27d6c3be7f92d     0.105494
# 2  f6ece71dae81d6b16bfb24ad6dd5611472d4c673     0.111101
# 3  b4d5c57c9b38ff5a12954fa01e11931b4e6bfbbb     0.104012
# 4  0899bf144249458ea9c89188473694bf44c7ca15     0.109086

# %%
ensemble_basebid_preds.head()
# Out:
#                                       bidid  predicted_payprice
# 0  bbcb813b6166538503d8b33a5602d7d72f6019dc           67.205068
# 1  5a07316c49477cb5d9b4d5aa39c27d6c3be7f92d           77.476141
# 2  f6ece71dae81d6b16bfb24ad6dd5611472d4c673           78.094520
# 3  b4d5c57c9b38ff5a12954fa01e11931b4e6bfbbb           45.960159
# 4  0899bf144249458ea9c89188473694bf44c7ca15           49.426684

# %%
base_bid = train.loc[ train["click"] == 1, "payprice"].mean()
avgCTR = train["click"].sum()*100/train.shape[0]

# %%
print("Base bid: {}, avgCTR: {}, ratio: {}".format(base_bid, avgCTR, base_bid/avgCTR))
# Out:
# Base bid: 105.46402677077523, avgCTR: 0.07375623256619447, ratio: 1429.899862037066

# %% [markdown]
# # Strategies

# %%
def Strategy1(sub_pCTR, sub_basebid):
    
    #avgCTR = train["click"].sum()*100/train.shape[0]
    avgCTR = sub_pCTR["click_proba"].mean()
    base_bid = train.loc[ train["click"] == 1, "payprice"].mean()
    bidprice = (sub_pCTR["click_proba"] * base_bid) / avgCTR
    return bidprice

def Strategy2(sub_pCTR, sub_basebid):
    
    #avgCTR = 0.5
    avgCTR = sub_pCTR["click_proba"].mean()
    bidprice = (sub_pCTR["click_proba"] * sub_basebid["predicted_payprice"]) / avgCTR
    return bidprice

def Strategy3(sub_pCTR, sub_basebid):
    
    #avgCTR = 0.5
    avgCTR = sub_pCTR["click_proba"].mean()
    sub_pCTR_ = sub_pCTR.copy()
    sub_pCTR_["click_proba"] = sub_pCTR_["click_proba"].map(lambda x: 0 if x <0.3 else np.exp(x))
    bidprice = (sub_pCTR_["click_proba"] * sub_basebid["predicted_payprice"]) / avgCTR
    return bidprice

def Strategy4(sub_pCTR, sub_basebid):
    
    #avgCTR = 0.5
    avgCTR = sub_pCTR["click_proba"].mean()
    sub_pCTR_ = sub_pCTR.copy()
    sub_pCTR_["click_proba"] = (sub_pCTR_["click_proba"] + 0.5)**2 - 0.5
    sub_pCTR_.loc[sub_pCTR_["click_proba"] < 0, "click_proba"] = 0
    bidprice = (sub_pCTR_["click_proba"] * sub_basebid["predicted_payprice"]) / avgCTR
    return bidprice

# %% [markdown]
# # Evaluate Results

# %%
budget = 6250*1000

def ValidationDataFrame(submission_pCTR, submission_basebid, strategy):
    
    validation_check = validation[["bidid", "click", "bidprice", "payprice"]]
    validation_check["click_proba"] = submission_pCTR["click_proba"]
    validation_check["basebid_predicted"] = submission_basebid["predicted_payprice"]
    validation_check["bidprice_predicted"] = strategy(submission_pCTR, submission_basebid)
    
    return validation_check


def ValidateStrategy(df):
    
    impressions = 0
    clicks = 0
    cost = 0
    auctions_participated = 0
    balance = budget
    
    for row in df.iterrows():
        
        if cost < budget:
            
            auctions_participated+=1
            
            if (row[1]["bidprice_predicted"] >= row[1]["payprice"]):
                
                if (balance > row[1]["bidprice_predicted"]):
                    
                    impressions+=1
                    clicks+=row[1]["click"]
                    cost+=row[1]["payprice"]
                    balance-=row[1]["payprice"]
                else:
                    pass
    
        else:
            break
    
    # Metrics
    ctr = clicks*100/impressions
    cpm = cost/(impressions*1000)
    cpc = cost/clicks
    
    print("Strategy statistics:")
    print("Auctions participated: {} | Impressions: {} | Clicks: {} | Cost: {} | CTR: {} | CPM: {} | CPC: {}".format(auctions_participated, \
                                                                                                                     impressions, clicks, cost,\
                                                                                                                     ctr, cpm, cpc))
    print("\n")
            
    return impressions, clicks, cost, auctions_participated, ctr, cpm, cpc

# def StrategyResults(impressions, clicks, cost):
#     ctr = clicks*100/impressions
#     spend = cost
#     cpm = cost/(impressions*1000)
#     if clicks > 0:
#         cpc = cost/clicks
#     else:
#         cpc = np.inf
        
#     print("Strategy results")
#     print("CTR: {} | Clicks: {} | Spend: {} | CPM: {} | CPC: {}".format(ctr, clicks, spend, cpm, cpc))
#     print("\n")
        
#     return ctr, clicks, spend, cpm, cpc

# %%
pCTR_preds = [ensemble_pCTR_preds, lr_preds, rf_preds, xgb_preds, dwane_preds]
basebid_preds = [ensemble_basebid_preds, lasso_preds, ridge_preds, elasticnet_preds, rfg_preds, xgbr_preds]
pCTR_model_names = ["Ensemble", "Logistic Regression", "Random Forest", "XGBoost", "Dwane Model"]
basebid_model_names = ["Ensemble", "Lasso", "Ridge", "Elastic Net", "Random Forest Regressor", "XGBoost Regressor"]
results = pd.DataFrame(columns = ["pCTR_model", "basebid_model", "Strategy", "Impressions", "Clicks", "Cost", "CTR", "CPM", "CPC"])
i=0
j=0
k=0

start = time.time()

for pCTR_pred in pCTR_preds:
    for basebid_pred in basebid_preds:
        
        # Strategy 1
        validation_check = ValidationDataFrame(pCTR_pred, basebid_pred, Strategy1)
        print("\033[1m pCTR model: {} \033[0m, \033[1m basebid model: {} \033[0m, \033[1m Strategy 1 \033[0m ".format(pCTR_model_names[i], basebid_model_names[j]))
        impressions, clicks, cost, auctions_participated, ctr, cpm, cpc = ValidateStrategy(validation_check)
        results.loc[k] = [pCTR_model_names[i], basebid_model_names[j], "Strategy1", impressions, clicks, cost, ctr, cpm, cpc]
        k+=1
        
        # Strategy 2
        validation_check = ValidationDataFrame(pCTR_pred, basebid_pred, Strategy2)
        print("\033[1m pCTR model: {} \033[0m, \033[1m basebid model: {} \033[0m, \033[1m Strategy 2 \033[0m ".format(pCTR_model_names[i], basebid_model_names[j]))
        impressions, clicks, cost, auctions_participated, ctr, cpm, cpc = ValidateStrategy(validation_check)
        results.loc[k] = [pCTR_model_names[i], basebid_model_names[j], "Strategy2", impressions, clicks, cost, ctr, cpm, cpc]
        k+=1
        
        # Strategy 3
        validation_check = ValidationDataFrame(pCTR_pred, basebid_pred, Strategy3)
        print("\033[1m pCTR model: {} \033[0m, \033[1m basebid model: {} \033[0m, \033[1m Strategy 3 \033[0m ".format(pCTR_model_names[i], basebid_model_names[j]))
        impressions, clicks, cost, auctions_participated, ctr, cpm, cpc= ValidateStrategy(validation_check)
        results.loc[k] = [pCTR_model_names[i], basebid_model_names[j], "Strategy3", impressions, clicks, cost, ctr, cpm, cpc]
        k+=1
        
        # Strategy 4
        validation_check = ValidationDataFrame(pCTR_pred, basebid_pred, Strategy4)
        print("\033[1m pCTR model: {} \033[0m, \033[1m basebid model: {} \033[0m, \033[1m Strategy 4 \033[0m ".format(pCTR_model_names[i], basebid_model_names[j]))
        impressions, clicks, cost, auctions_participated, ctr, cpm, cpc= ValidateStrategy(validation_check)
        results.loc[k] = [pCTR_model_names[i], basebid_model_names[j], "Strategy4", impressions, clicks, cost, ctr, cpm, cpc]
        k+=1
        
        j+=1
        
        
    j=0    
    i+=1
    
end = time.time()
print("Total time: {} mins".format((end-start)/60))
# Out:
#  pCTR model: Ensemble ,  basebid model: Ensemble ,  Strategy 1
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 124625 | Clicks: 99 | Cost: 6249953 | CTR: 0.0794383149448345 | CPM: 0.050150074222668005 | CPC: 63130.83838383838
#
#
#  pCTR model: Ensemble ,  basebid model: Ensemble ,  Strategy 2
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 131277 | Clicks: 133 | Cost: 6249995 | CTR: 0.10131249190642687 | CPM: 0.047609215628023185 | CPC: 46992.44360902256
#
#
#  pCTR model: Ensemble ,  basebid model: Ensemble ,  Strategy 3
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 44078 | Clicks: 144 | Cost: 3922319 | CTR: 0.326693588638323 | CPM: 0.08898586596488044 | CPC: 27238.32638888889
#
#
#  pCTR model: Ensemble ,  basebid model: Ensemble ,  Strategy 4
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 39865 | Clicks: 136 | Cost: 2834671 | CTR: 0.3411513859275053 | CPM: 0.07110676031606672 | CPC: 20843.16911764706
#
#
#  pCTR model: Ensemble ,  basebid model: Lasso ,  Strategy 1
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 124625 | Clicks: 99 | Cost: 6249953 | CTR: 0.0794383149448345 | CPM: 0.050150074222668005 | CPC: 63130.83838383838
#
#
#  pCTR model: Ensemble ,  basebid model: Lasso ,  Strategy 2
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 136222 | Clicks: 137 | Cost: 6249991 | CTR: 0.10057112654343645 | CPM: 0.045880922317980945 | CPC: 45620.37226277372
#
#
#  pCTR model: Ensemble ,  basebid model: Lasso ,  Strategy 3
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 44077 | Clicks: 144 | Cost: 3922067 | CTR: 0.3267010005218141 | CPM: 0.08898216757038818 | CPC: 27236.57638888889
#
#
#  pCTR model: Ensemble ,  basebid model: Lasso ,  Strategy 4
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 39266 | Clicks: 136 | Cost: 2702910 | CTR: 0.3463556257321856 | CPM: 0.06883588855498396 | CPC: 19874.33823529412
#
#
#  pCTR model: Ensemble ,  basebid model: Ridge ,  Strategy 1
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 124625 | Clicks: 99 | Cost: 6249953 | CTR: 0.0794383149448345 | CPM: 0.050150074222668005 | CPC: 63130.83838383838
#
#
#  pCTR model: Ensemble ,  basebid model: Ridge ,  Strategy 2
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 131053 | Clicks: 136 | Cost: 6249996 | CTR: 0.10377480866519652 | CPM: 0.04769059846016497 | CPC: 45955.85294117647
#
#
#  pCTR model: Ensemble ,  basebid model: Ridge ,  Strategy 3
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 44038 | Clicks: 144 | Cost: 3914078 | CTR: 0.3269903265361733 | CPM: 0.08887955856305918 | CPC: 27181.097222222223
#
#
#  pCTR model: Ensemble ,  basebid model: Ridge ,  Strategy 4
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 39514 | Clicks: 139 | Cost: 2798937 | CTR: 0.3517740547653996 | CPM: 0.07083405881459735 | CPC: 20136.237410071943
#
#
#  pCTR model: Ensemble ,  basebid model: Elastic Net ,  Strategy 1
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 124625 | Clicks: 99 | Cost: 6249953 | CTR: 0.0794383149448345 | CPM: 0.050150074222668005 | CPC: 63130.83838383838
#
#
#  pCTR model: Ensemble ,  basebid model: Elastic Net ,  Strategy 2
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 135265 | Clicks: 137 | Cost: 6249996 | CTR: 0.10128266735667024 | CPM: 0.0462055668502569 | CPC: 45620.40875912409
#
#
#  pCTR model: Ensemble ,  basebid model: Elastic Net ,  Strategy 3
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 44078 | Clicks: 144 | Cost: 3922319 | CTR: 0.326693588638323 | CPM: 0.08898586596488044 | CPC: 27238.32638888889
#
#
#  pCTR model: Ensemble ,  basebid model: Elastic Net ,  Strategy 4
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 39148 | Clicks: 136 | Cost: 2703565 | CTR: 0.34739961172984574 | CPM: 0.06906010524164709 | CPC: 19879.154411764706
#
#
#  pCTR model: Ensemble ,  basebid model: Random Forest Regressor ,  Strategy 1
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 124625 | Clicks: 99 | Cost: 6249953 | CTR: 0.0794383149448345 | CPM: 0.050150074222668005 | CPC: 63130.83838383838
#
#
#  pCTR model: Ensemble ,  basebid model: Random Forest Regressor ,  Strategy 2
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 123082 | Clicks: 134 | Cost: 6249996 | CTR: 0.10887050909149998 | CPM: 0.050779122861181976 | CPC: 46641.76119402985
#
#
#  pCTR model: Ensemble ,  basebid model: Random Forest Regressor ,  Strategy 3
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 44010 | Clicks: 144 | Cost: 3909215 | CTR: 0.32719836400818 | CPM: 0.08882560781640536 | CPC: 27147.32638888889
#
#
#  pCTR model: Ensemble ,  basebid model: Random Forest Regressor ,  Strategy 4
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 39582 | Clicks: 137 | Cost: 2906100 | CTR: 0.3461169218331565 | CPM: 0.07341973624374716 | CPC: 21212.408759124086
#
#
#  pCTR model: Ensemble ,  basebid model: XGBoost Regressor ,  Strategy 1
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 124625 | Clicks: 99 | Cost: 6249953 | CTR: 0.0794383149448345 | CPM: 0.050150074222668005 | CPC: 63130.83838383838
#
#
#  pCTR model: Ensemble ,  basebid model: XGBoost Regressor ,  Strategy 2
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 122111 | Clicks: 131 | Cost: 6249997 | CTR: 0.10727944247446995 | CPM: 0.05118291554405418 | CPC: 47709.900763358775
#
#
#  pCTR model: Ensemble ,  basebid model: XGBoost Regressor ,  Strategy 3
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 44008 | Clicks: 144 | Cost: 3913804 | CTR: 0.32721323395746227 | CPM: 0.0889339211052536 | CPC: 27179.194444444445
#
#
#  pCTR model: Ensemble ,  basebid model: XGBoost Regressor ,  Strategy 4
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 39805 | Clicks: 137 | Cost: 2937057 | CTR: 0.34417786710212284 | CPM: 0.07378613239542771 | CPC: 21438.372262773722
#
#
#  pCTR model: Logistic Regression ,  basebid model: Ensemble ,  Strategy 1
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 122870 | Clicks: 68 | Cost: 6249925 | CTR: 0.05534304549523887 | CPM: 0.050866159355416295 | CPC: 91910.66176470589
#
#
#  pCTR model: Logistic Regression ,  basebid model: Ensemble ,  Strategy 2
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 137137 | Clicks: 96 | Cost: 6249997 | CTR: 0.07000298971101891 | CPM: 0.04557484121717698 | CPC: 65104.135416666664
#
#
#  pCTR model: Logistic Regression ,  basebid model: Ensemble ,  Strategy 3
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 81636 | Clicks: 52 | Cost: 6249987 | CTR: 0.06369738840707531 | CPM: 0.07655920182272527 | CPC: 120192.05769230769
#
#
#  pCTR model: Logistic Regression ,  basebid model: Ensemble ,  Strategy 4
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 147914 | Clicks: 113 | Cost: 6249990 | CTR: 0.07639574347255838 | CPM: 0.04225421528726152 | CPC: 55309.64601769912
#
#
#  pCTR model: Logistic Regression ,  basebid model: Lasso ,  Strategy 1
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 122870 | Clicks: 68 | Cost: 6249925 | CTR: 0.05534304549523887 | CPM: 0.050866159355416295 | CPC: 91910.66176470589
#
#
#  pCTR model: Logistic Regression ,  basebid model: Lasso ,  Strategy 2
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 142482 | Clicks: 93 | Cost: 6249982 | CTR: 0.06527140270349939 | CPM: 0.043865063657163715 | CPC: 67204.10752688172
#  pCTR model: Logistic Regression ,  basebid model: Lasso ,  Strategy 3
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 82376 | Clicks: 53 | Cost: 6249967 | CTR: 0.06433912790133048 | CPM: 0.07587121248907448 | CPC: 117923.90566037736
#
#
#  pCTR model: Logistic Regression ,  basebid model: Lasso ,  Strategy 4
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 152951 | Clicks: 122 | Cost: 6202455 | CTR: 0.07976410745925165 | CPM: 0.040551908781243665 | CPC: 50839.79508196721
#
#
#  pCTR model: Logistic Regression ,  basebid model: Ridge ,  Strategy 1
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 122870 | Clicks: 68 | Cost: 6249925 | CTR: 0.05534304549523887 | CPM: 0.050866159355416295 | CPC: 91910.66176470589
#
#
#  pCTR model: Logistic Regression ,  basebid model: Ridge ,  Strategy 2
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 138439 | Clicks: 92 | Cost: 6249995 | CTR: 0.06645526188429561 | CPM: 0.04514620157614545 | CPC: 67934.72826086957
#
#
#  pCTR model: Logistic Regression ,  basebid model: Ridge ,  Strategy 3
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 82248 | Clicks: 54 | Cost: 6249993 | CTR: 0.06565509191712868 | CPM: 0.07598960461044646 | CPC: 115740.61111111111
#
#
#  pCTR model: Logistic Regression ,  basebid model: Ridge ,  Strategy 4
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 148521 | Clicks: 117 | Cost: 6249997 | CTR: 0.07877673864302018 | CPM: 0.04208157095629574 | CPC: 53418.77777777778
#
#
#  pCTR model: Logistic Regression ,  basebid model: Elastic Net ,  Strategy 1
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 122870 | Clicks: 68 | Cost: 6249925 | CTR: 0.05534304549523887 | CPM: 0.050866159355416295 | CPC: 91910.66176470589
#
#
#  pCTR model: Logistic Regression ,  basebid model: Elastic Net ,  Strategy 2
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 142566 | Clicks: 91 | Cost: 6249995 | CTR: 0.06383008571468653 | CPM: 0.04383930951278706 | CPC: 68681.26373626373
#
#
#  pCTR model: Logistic Regression ,  basebid model: Elastic Net ,  Strategy 3
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 81960 | Clicks: 52 | Cost: 6249957 | CTR: 0.0634455832113226 | CPM: 0.0762561859443631 | CPC: 120191.48076923077
#
#
#  pCTR model: Logistic Regression ,  basebid model: Elastic Net ,  Strategy 4
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 153168 | Clicks: 114 | Cost: 6249986 | CTR: 0.07442807897210905 | CPM: 0.04080477645461193 | CPC: 54824.43859649123
#
#
#  pCTR model: Logistic Regression ,  basebid model: Random Forest Regressor ,  Strategy 1
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 122870 | Clicks: 68 | Cost: 6249925 | CTR: 0.05534304549523887 | CPM: 0.050866159355416295 | CPC: 91910.66176470589
#
#
#  pCTR model: Logistic Regression ,  basebid model: Random Forest Regressor ,  Strategy 2
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 127586 | Clicks: 95 | Cost: 6249996 | CTR: 0.07445958020472465 | CPM: 0.04898653457275877 | CPC: 65789.43157894736
#
#
#  pCTR model: Logistic Regression ,  basebid model: Random Forest Regressor ,  Strategy 3
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 82819 | Clicks: 54 | Cost: 6249989 | CTR: 0.06520242939422113 | CPM: 0.07546564194206644 | CPC: 115740.53703703704
#
#
#  pCTR model: Logistic Regression ,  basebid model: Random Forest Regressor ,  Strategy 4
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 137938 | Clicks: 109 | Cost: 6249997 | CTR: 0.07902100943902333 | CPM: 0.04531019008540069 | CPC: 57339.422018348625
#
#
#  pCTR model: Logistic Regression ,  basebid model: XGBoost Regressor ,  Strategy 1
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 122870 | Clicks: 68 | Cost: 6249925 | CTR: 0.05534304549523887 | CPM: 0.050866159355416295 | CPC: 91910.66176470589
#
#
#  pCTR model: Logistic Regression ,  basebid model: XGBoost Regressor ,  Strategy 2
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 125689 | Clicks: 89 | Cost: 6249998 | CTR: 0.07080969695040934 | CPM: 0.04972589486749039 | CPC: 70224.69662921349
#
#
#  pCTR model: Logistic Regression ,  basebid model: XGBoost Regressor ,  Strategy 3
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 82413 | Clicks: 54 | Cost: 6249998 | CTR: 0.06552364311455718 | CPM: 0.07583752563309187 | CPC: 115740.70370370371
#
#
#  pCTR model: Logistic Regression ,  basebid model: XGBoost Regressor ,  Strategy 4
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 136678 | Clicks: 107 | Cost: 6249996 | CTR: 0.07828619090124234 | CPM: 0.04572788598018701 | CPC: 58411.17757009346
#
#
#  pCTR model: Random Forest ,  basebid model: Ensemble ,  Strategy 1
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 122112 | Clicks: 110 | Cost: 6249998 | CTR: 0.09008123689727464 | CPM: 0.05118250458595388 | CPC: 56818.163636363635
#
#
#  pCTR model: Random Forest ,  basebid model: Ensemble ,  Strategy 2
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 122352 | Clicks: 134 | Cost: 6249999 | CTR: 0.10952007323133255 | CPM: 0.05108211553550412 | CPC: 46641.78358208955
#
#
#  pCTR model: Random Forest ,  basebid model: Ensemble ,  Strategy 3
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 14132 | Clicks: 115 | Cost: 1162144 | CTR: 0.8137560147183697 | CPM: 0.08223492782337956 | CPC: 10105.6
#
#
#  pCTR model: Random Forest ,  basebid model: Ensemble ,  Strategy 4
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 16872 | Clicks: 118 | Cost: 1164960 | CTR: 0.6993835941204363 | CPM: 0.06904694167852063 | CPC: 9872.542372881357
#
#
#  pCTR model: Random Forest ,  basebid model: Lasso ,  Strategy 1
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 122112 | Clicks: 110 | Cost: 6249998 | CTR: 0.09008123689727464 | CPM: 0.05118250458595388 | CPC: 56818.163636363635
#
#
#  pCTR model: Random Forest ,  basebid model: Lasso ,  Strategy 2
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 127526 | Clicks: 134 | Cost: 6249997 | CTR: 0.10507661182817621 | CPM: 0.04900959020121387 | CPC: 46641.76865671642
#
#
#  pCTR model: Random Forest ,  basebid model: Lasso ,  Strategy 3
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 14132 | Clicks: 115 | Cost: 1162144 | CTR: 0.8137560147183697 | CPM: 0.08223492782337956 | CPC: 10105.6
#
#
#  pCTR model: Random Forest ,  basebid model: Lasso ,  Strategy 4
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 16702 | Clicks: 115 | Cost: 1125332 | CTR: 0.6885402945754999 | CPM: 0.067377080589151 | CPC: 9785.495652173913
#
#
#  pCTR model: Random Forest ,  basebid model: Ridge ,  Strategy 1
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 122112 | Clicks: 110 | Cost: 6249998 | CTR: 0.09008123689727464 | CPM: 0.05118250458595388 | CPC: 56818.163636363635
#
#
#  pCTR model: Random Forest ,  basebid model: Ridge ,  Strategy 2
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 122979 | Clicks: 136 | Cost: 6249997 | CTR: 0.11058798656681222 | CPM: 0.050821660608721814 | CPC: 45955.86029411765
#
#
#  pCTR model: Random Forest ,  basebid model: Ridge ,  Strategy 3
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 14118 | Clicks: 115 | Cost: 1159212 | CTR: 0.8145629692591019 | CPM: 0.082108797280068 | CPC: 10080.104347826087
#
#
#  pCTR model: Random Forest ,  basebid model: Ridge ,  Strategy 4
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 16621 | Clicks: 116 | Cost: 1139839 | CTR: 0.6979122796462307 | CPM: 0.06857824438962758 | CPC: 9826.198275862069
#
#
#  pCTR model: Random Forest ,  basebid model: Elastic Net ,  Strategy 1
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 122112 | Clicks: 110 | Cost: 6249998 | CTR: 0.09008123689727464 | CPM: 0.05118250458595388 | CPC: 56818.163636363635
#
#
#  pCTR model: Random Forest ,  basebid model: Elastic Net ,  Strategy 2
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 126848 | Clicks: 134 | Cost: 6249996 | CTR: 0.10563824419778002 | CPM: 0.04927153758829465 | CPC: 46641.76119402985
#
#
#  pCTR model: Random Forest ,  basebid model: Elastic Net ,  Strategy 3
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 14132 | Clicks: 115 | Cost: 1162144 | CTR: 0.8137560147183697 | CPM: 0.08223492782337956 | CPC: 10105.6
#
#
#  pCTR model: Random Forest ,  basebid model: Elastic Net ,  Strategy 4
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 16663 | Clicks: 118 | Cost: 1129703 | CTR: 0.7081557942747404 | CPM: 0.06779709536097941 | CPC: 9573.754237288136
#
#
#  pCTR model: Random Forest ,  basebid model: Random Forest Regressor ,  Strategy 1
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 122112 | Clicks: 110 | Cost: 6249998 | CTR: 0.09008123689727464 | CPM: 0.05118250458595388 | CPC: 56818.163636363635
#
#
#  pCTR model: Random Forest ,  basebid model: Random Forest Regressor ,  Strategy 2
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 114862 | Clicks: 133 | Cost: 6249996 | CTR: 0.11579112326095663 | CPM: 0.05441308700875833 | CPC: 46992.45112781955
#
#
#  pCTR model: Random Forest ,  basebid model: Random Forest Regressor ,  Strategy 3
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 14130 | Clicks: 115 | Cost: 1161935 | CTR: 0.8138711960368011 | CPM: 0.08223177636234962 | CPC: 10103.782608695652
#
#
#  pCTR model: Random Forest ,  basebid model: Random Forest Regressor ,  Strategy 4
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 16771 | Clicks: 118 | Cost: 1183232 | CTR: 0.7035954922187109 | CPM: 0.07055226283465506 | CPC: 10027.389830508475
#
#
#  pCTR model: Random Forest ,  basebid model: XGBoost Regressor ,  Strategy 1
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 122112 | Clicks: 110 | Cost: 6249998 | CTR: 0.09008123689727464 | CPM: 0.05118250458595388 | CPC: 56818.163636363635
#
#
#  pCTR model: Random Forest ,  basebid model: XGBoost Regressor ,  Strategy 2
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 113964 | Clicks: 128 | Cost: 6249999 | CTR: 0.11231617001860236 | CPM: 0.05484187111719491 | CPC: 48828.1171875
#
#
#  pCTR model: Random Forest ,  basebid model: XGBoost Regressor ,  Strategy 3
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 14126 | Clicks: 115 | Cost: 1161344 | CTR: 0.8141016565198924 | CPM: 0.08221322384255982 | CPC: 10098.64347826087
#
#
#  pCTR model: Random Forest ,  basebid model: XGBoost Regressor ,  Strategy 4
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 16858 | Clicks: 117 | Cost: 1195477 | CTR: 0.694032506821687 | CPM: 0.07091452129552735 | CPC: 10217.752136752137
#
#
#  pCTR model: XGBoost ,  basebid model: Ensemble ,  Strategy 1
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 115614 | Clicks: 144 | Cost: 6249999 | CTR: 0.12455238984898023 | CPM: 0.054059188333592814 | CPC: 43402.770833333336
#
#
#  pCTR model: XGBoost ,  basebid model: Ensemble ,  Strategy 2
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 103711 | Clicks: 160 | Cost: 5942123 | CTR: 0.1542748599473537 | CPM: 0.05729501210093433 | CPC: 37138.26875
#
#
#  pCTR model: XGBoost ,  basebid model: Ensemble ,  Strategy 3
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 6897 | Clicks: 101 | Cost: 581952 | CTR: 1.4644048136871104 | CPM: 0.08437755545889518 | CPC: 5761.9009900990095
#
#
#  pCTR model: XGBoost ,  basebid model: Ensemble ,  Strategy 4
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 10017 | Clicks: 108 | Cost: 784148 | CTR: 1.0781671159029649 | CPM: 0.0782817210741739 | CPC: 7260.62962962963
#
#
#  pCTR model: XGBoost ,  basebid model: Lasso ,  Strategy 1
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 115614 | Clicks: 144 | Cost: 6249999 | CTR: 0.12455238984898023 | CPM: 0.054059188333592814 | CPC: 43402.770833333336
#
#
#  pCTR model: XGBoost ,  basebid model: Lasso ,  Strategy 2
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 104900 | Clicks: 160 | Cost: 5731960 | CTR: 0.15252621544327932 | CPM: 0.054642135367016204 | CPC: 35824.75
#
#
#  pCTR model: XGBoost ,  basebid model: Lasso ,  Strategy 3
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 6897 | Clicks: 101 | Cost: 581952 | CTR: 1.4644048136871104 | CPM: 0.08437755545889518 | CPC: 5761.9009900990095
#
#
#  pCTR model: XGBoost ,  basebid model: Lasso ,  Strategy 4
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 9947 | Clicks: 108 | Cost: 771024 | CTR: 1.0857544988438725 | CPM: 0.07751322006635167 | CPC: 7139.111111111111
#
#
#  pCTR model: XGBoost ,  basebid model: Ridge ,  Strategy 1
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 115614 | Clicks: 144 | Cost: 6249999 | CTR: 0.12455238984898023 | CPM: 0.054059188333592814 | CPC: 43402.770833333336
#
#
#  pCTR model: XGBoost ,  basebid model: Ridge ,  Strategy 2
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 102969 | Clicks: 157 | Cost: 5861943 | CTR: 0.15247307442045666 | CPM: 0.056929201992832794 | CPC: 37337.21656050955
#
#
#  pCTR model: XGBoost ,  basebid model: Ridge ,  Strategy 3
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 6896 | Clicks: 101 | Cost: 581932 | CTR: 1.46461716937355 | CPM: 0.0843868909512761 | CPC: 5761.702970297029
#
#
#  pCTR model: XGBoost ,  basebid model: Ridge ,  Strategy 4
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 9954 | Clicks: 107 | Cost: 775860 | CTR: 1.074944745830822 | CPM: 0.07794454490657023 | CPC: 7251.028037383177
#
#
#  pCTR model: XGBoost ,  basebid model: Elastic Net ,  Strategy 1
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 115614 | Clicks: 144 | Cost: 6249999 | CTR: 0.12455238984898023 | CPM: 0.054059188333592814 | CPC: 43402.770833333336
#
#
#  pCTR model: XGBoost ,  basebid model: Elastic Net ,  Strategy 2
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 104562 | Clicks: 160 | Cost: 5774405 | CTR: 0.15301926129951607 | CPM: 0.05522469922151451 | CPC: 36090.03125
#
#
#  pCTR model: XGBoost ,  basebid model: Elastic Net ,  Strategy 3
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 6897 | Clicks: 101 | Cost: 581952 | CTR: 1.4644048136871104 | CPM: 0.08437755545889518 | CPC: 5761.9009900990095
#
#
#  pCTR model: XGBoost ,  basebid model: Elastic Net ,  Strategy 4
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 9954 | Clicks: 108 | Cost: 772797 | CTR: 1.0849909584086799 | CPM: 0.07763682941531043 | CPC: 7155.527777777777
#
#
#  pCTR model: XGBoost ,  basebid model: Random Forest Regressor ,  Strategy 1
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 115614 | Clicks: 144 | Cost: 6249999 | CTR: 0.12455238984898023 | CPM: 0.054059188333592814 | CPC: 43402.770833333336
#
#
#  pCTR model: XGBoost ,  basebid model: Random Forest Regressor ,  Strategy 2
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 99688 | Clicks: 160 | Cost: 6020706 | CTR: 0.1605007623786213 | CPM: 0.06039549394109622 | CPC: 37629.4125
#
#
#  pCTR model: XGBoost ,  basebid model: Random Forest Regressor ,  Strategy 3
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 6897 | Clicks: 101 | Cost: 581952 | CTR: 1.4644048136871104 | CPM: 0.08437755545889518 | CPC: 5761.9009900990095
#
#
#  pCTR model: XGBoost ,  basebid model: Random Forest Regressor ,  Strategy 4
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 10026 | Clicks: 108 | Cost: 792043 | CTR: 1.0771992818671454 | CPM: 0.07899890285258328 | CPC: 7333.731481481482
#
#
#  pCTR model: XGBoost ,  basebid model: XGBoost Regressor ,  Strategy 1
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 115614 | Clicks: 144 | Cost: 6249999 | CTR: 0.12455238984898023 | CPM: 0.054059188333592814 | CPC: 43402.770833333336
#
#
#  pCTR model: XGBoost ,  basebid model: XGBoost Regressor ,  Strategy 2
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 99517 | Clicks: 158 | Cost: 6046435 | CTR: 0.15876684385582363 | CPM: 0.06075781022337892 | CPC: 38268.57594936709
#
#
#  pCTR model: XGBoost ,  basebid model: XGBoost Regressor ,  Strategy 3
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 6894 | Clicks: 101 | Cost: 581818 | CTR: 1.4650420655642589 | CPM: 0.08439483608935307 | CPC: 5760.574257425743
#
#
#  pCTR model: XGBoost ,  basebid model: XGBoost Regressor ,  Strategy 4
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 10008 | Clicks: 108 | Cost: 792198 | CTR: 1.079136690647482 | CPM: 0.07915647482014389 | CPC: 7335.166666666667
#
#
#  pCTR model: Dwane Model ,  basebid model: Ensemble ,  Strategy 1
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 76822 | Clicks: 160 | Cost: 5990518 | CTR: 0.2082736716044883 | CPM: 0.0779791986670485 | CPC: 37440.7375
#
#
#  pCTR model: Dwane Model ,  basebid model: Ensemble ,  Strategy 2
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 73746 | Clicks: 159 | Cost: 5802320 | CTR: 0.21560491416483607 | CPM: 0.07867979280232149 | CPC: 36492.5786163522
#
#
#  pCTR model: Dwane Model ,  basebid model: Ensemble ,  Strategy 3
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 59969 | Clicks: 157 | Cost: 5346476 | CTR: 0.2618019309976821 | CPM: 0.08915399623138621 | CPC: 34053.987261146496
#
#
#  pCTR model: Dwane Model ,  basebid model: Ensemble ,  Strategy 4
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 55523 | Clicks: 150 | Cost: 4719281 | CTR: 0.270158312771284 | CPM: 0.08499686616357185 | CPC: 31461.873333333333
#
#
#  pCTR model: Dwane Model ,  basebid model: Lasso ,  Strategy 1
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 76822 | Clicks: 160 | Cost: 5990518 | CTR: 0.2082736716044883 | CPM: 0.0779791986670485 | CPC: 37440.7375
#
#
#  pCTR model: Dwane Model ,  basebid model: Lasso ,  Strategy 2
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 73482 | Clicks: 157 | Cost: 5695993 | CTR: 0.21365776652785717 | CPM: 0.07751548678587954 | CPC: 36280.210191082806
#
#
#  pCTR model: Dwane Model ,  basebid model: Lasso ,  Strategy 3
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 59969 | Clicks: 157 | Cost: 5346476 | CTR: 0.2618019309976821 | CPM: 0.08915399623138621 | CPC: 34053.987261146496
#
#
#  pCTR model: Dwane Model ,  basebid model: Lasso ,  Strategy 4
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 55294 | Clicks: 149 | Cost: 4664094 | CTR: 0.2694686584439541 | CPM: 0.08435081564003327 | CPC: 31302.644295302012
#
#
#  pCTR model: Dwane Model ,  basebid model: Ridge ,  Strategy 1
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 76822 | Clicks: 160 | Cost: 5990518 | CTR: 0.2082736716044883 | CPM: 0.0779791986670485 | CPC: 37440.7375
#
#
#  pCTR model: Dwane Model ,  basebid model: Ridge ,  Strategy 2
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 73498 | Clicks: 159 | Cost: 5767255 | CTR: 0.21633241720863153 | CPM: 0.07846818961060165 | CPC: 36272.044025157236
#
#
#  pCTR model: Dwane Model ,  basebid model: Ridge ,  Strategy 3
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 59963 | Clicks: 157 | Cost: 5345680 | CTR: 0.2618281273451962 | CPM: 0.08914964227940564 | CPC: 34048.91719745223
#
#
#  pCTR model: Dwane Model ,  basebid model: Ridge ,  Strategy 4
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 55585 | Clicks: 148 | Cost: 4712867 | CTR: 0.2662588827921202 | CPM: 0.08478666906539534 | CPC: 31843.695945945947
#
#
#  pCTR model: Dwane Model ,  basebid model: Elastic Net ,  Strategy 1
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 76822 | Clicks: 160 | Cost: 5990518 | CTR: 0.2082736716044883 | CPM: 0.0779791986670485 | CPC: 37440.7375
#
#
#  pCTR model: Dwane Model ,  basebid model: Elastic Net ,  Strategy 2
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 73385 | Clicks: 159 | Cost: 5724745 | CTR: 0.21666553110308645 | CPM: 0.07800974313551816 | CPC: 36004.6855345912
#
#
#  pCTR model: Dwane Model ,  basebid model: Elastic Net ,  Strategy 3
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 59969 | Clicks: 157 | Cost: 5346476 | CTR: 0.2618019309976821 | CPM: 0.08915399623138621 | CPC: 34053.987261146496
#
#
#  pCTR model: Dwane Model ,  basebid model: Elastic Net ,  Strategy 4
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 55268 | Clicks: 148 | Cost: 4672377 | CTR: 0.267786060649924 | CPM: 0.0845403669392777 | CPC: 31570.114864864863
#
#
#  pCTR model: Dwane Model ,  basebid model: Random Forest Regressor ,  Strategy 1
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 76822 | Clicks: 160 | Cost: 5990518 | CTR: 0.2082736716044883 | CPM: 0.0779791986670485 | CPC: 37440.7375
#
#
#  pCTR model: Dwane Model ,  basebid model: Random Forest Regressor ,  Strategy 2
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 72696 | Clicks: 160 | Cost: 5788614 | CTR: 0.22009464069549906 | CPM: 0.07962768240343347 | CPC: 36178.8375
#
#
#  pCTR model: Dwane Model ,  basebid model: Random Forest Regressor ,  Strategy 3
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 59948 | Clicks: 157 | Cost: 5341836 | CTR: 0.26189364115566827 | CPM: 0.08910782678321212 | CPC: 34024.43312101911
#
#
#  pCTR model: Dwane Model ,  basebid model: Random Forest Regressor ,  Strategy 4
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 55364 | Clicks: 151 | Cost: 4721042 | CTR: 0.27274040892999063 | CPM: 0.08527277653348747 | CPC: 31265.17880794702
#
#
#  pCTR model: Dwane Model ,  basebid model: XGBoost Regressor ,  Strategy 1
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 76822 | Clicks: 160 | Cost: 5990518 | CTR: 0.2082736716044883 | CPM: 0.0779791986670485 | CPC: 37440.7375
#
#
#  pCTR model: Dwane Model ,  basebid model: XGBoost Regressor ,  Strategy 2
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 72795 | Clicks: 158 | Cost: 5808658 | CTR: 0.21704787416718183 | CPM: 0.07979473864963253 | CPC: 36763.6582278481
#
#
#  pCTR model: Dwane Model ,  basebid model: XGBoost Regressor ,  Strategy 3
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 59888 | Clicks: 157 | Cost: 5339690 | CTR: 0.26215602457921455 | CPM: 0.08916126769970611 | CPC: 34010.76433121019
#
#
#  pCTR model: Dwane Model ,  basebid model: XGBoost Regressor ,  Strategy 4
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 55325 | Clicks: 148 | Cost: 4724848 | CTR: 0.2675101671938545 | CPM: 0.08540168097605061 | CPC: 31924.64864864865
#
#
# Total time: 52.790687648455304 mins

# %%
#results["CPM"] = results["CPM"]/1000
# results["CPC"] = results["CPC"]/1000

# %%
results.to_csv("ValidationSet_Evaluation_Results.csv")

# %%
pd.options.display.max_rows = results.shape[0]
results.sort_values(by = "Clicks", ascending = False)
# Out:
#               pCTR_model            basebid_model   Strategy Impressions  \
# 77               XGBoost                    Lasso  Strategy2      104900
# 96           Dwane Model                 Ensemble  Strategy1       76822
# 108          Dwane Model              Elastic Net  Strategy1       76822
# 104          Dwane Model                    Ridge  Strategy1       76822
# 116          Dwane Model        XGBoost Regressor  Strategy1       76822
# 100          Dwane Model                    Lasso  Strategy1       76822
# 113          Dwane Model  Random Forest Regressor  Strategy2       72696
# 112          Dwane Model  Random Forest Regressor  Strategy1       76822
# 89               XGBoost  Random Forest Regressor  Strategy2       99688
# 85               XGBoost              Elastic Net  Strategy2      104562
# 73               XGBoost                 Ensemble  Strategy2      103711
# 97           Dwane Model                 Ensemble  Strategy2       73746
# 105          Dwane Model                    Ridge  Strategy2       73498
# 109          Dwane Model              Elastic Net  Strategy2       73385
# 117          Dwane Model        XGBoost Regressor  Strategy2       72795
# 93               XGBoost        XGBoost Regressor  Strategy2       99517
# 101          Dwane Model                    Lasso  Strategy2       73482
# 81               XGBoost                    Ridge  Strategy2      102969
# 106          Dwane Model                    Ridge  Strategy3       59963
# 110          Dwane Model              Elastic Net  Strategy3       59969
# 98           Dwane Model                 Ensemble  Strategy3       59969
# 102          Dwane Model                    Lasso  Strategy3       59969
# 114          Dwane Model  Random Forest Regressor  Strategy3       59948
# 118          Dwane Model        XGBoost Regressor  Strategy3       59888
# 115          Dwane Model  Random Forest Regressor  Strategy4       55364
# 99           Dwane Model                 Ensemble  Strategy4       55523
# 103          Dwane Model                    Lasso  Strategy4       55294
# 119          Dwane Model        XGBoost Regressor  Strategy4       55325
# 111          Dwane Model              Elastic Net  Strategy4       55268
# 107          Dwane Model                    Ridge  Strategy4       55585
# 80               XGBoost                    Ridge  Strategy1      115614
# 2               Ensemble                 Ensemble  Strategy3       44078
# 72               XGBoost                 Ensemble  Strategy1      115614
# 84               XGBoost              Elastic Net  Strategy1      115614
# 88               XGBoost  Random Forest Regressor  Strategy1      115614
# 92               XGBoost        XGBoost Regressor  Strategy1      115614
# 6               Ensemble                    Lasso  Strategy3       44077
# 10              Ensemble                    Ridge  Strategy3       44038
# 22              Ensemble        XGBoost Regressor  Strategy3       44008
# 76               XGBoost                    Lasso  Strategy1      115614
# 14              Ensemble              Elastic Net  Strategy3       44078
# 18              Ensemble  Random Forest Regressor  Strategy3       44010
# 11              Ensemble                    Ridge  Strategy4       39514
# 19              Ensemble  Random Forest Regressor  Strategy4       39582
# 5               Ensemble                    Lasso  Strategy2      136222
# 23              Ensemble        XGBoost Regressor  Strategy4       39805
# 13              Ensemble              Elastic Net  Strategy2      135265
# 57         Random Forest                    Ridge  Strategy2      122979
# 9               Ensemble                    Ridge  Strategy2      131053
# 7               Ensemble                    Lasso  Strategy4       39266
# 15              Ensemble              Elastic Net  Strategy4       39148
# 3               Ensemble                 Ensemble  Strategy4       39865
# 17              Ensemble  Random Forest Regressor  Strategy2      123082
# 61         Random Forest              Elastic Net  Strategy2      126848
# 49         Random Forest                 Ensemble  Strategy2      122352
# 53         Random Forest                    Lasso  Strategy2      127526
# 65         Random Forest  Random Forest Regressor  Strategy2      114862
# 1               Ensemble                 Ensemble  Strategy2      131277
# 21              Ensemble        XGBoost Regressor  Strategy2      122111
# 69         Random Forest        XGBoost Regressor  Strategy2      113964
# 31   Logistic Regression                    Lasso  Strategy4      152951
# 63         Random Forest              Elastic Net  Strategy4       16663
# 51         Random Forest                 Ensemble  Strategy4       16872
# 67         Random Forest  Random Forest Regressor  Strategy4       16771
# 35   Logistic Regression                    Ridge  Strategy4      148521
# 71         Random Forest        XGBoost Regressor  Strategy4       16858
# 59         Random Forest                    Ridge  Strategy4       16621
# 70         Random Forest        XGBoost Regressor  Strategy3       14126
# 55         Random Forest                    Lasso  Strategy4       16702
# 50         Random Forest                 Ensemble  Strategy3       14132
# 66         Random Forest  Random Forest Regressor  Strategy3       14130
# 54         Random Forest                    Lasso  Strategy3       14132
# 62         Random Forest              Elastic Net  Strategy3       14132
# 58         Random Forest                    Ridge  Strategy3       14118
# 39   Logistic Regression              Elastic Net  Strategy4      153168
# 27   Logistic Regression                 Ensemble  Strategy4      147914
# 60         Random Forest              Elastic Net  Strategy1      122112
# 68         Random Forest        XGBoost Regressor  Strategy1      122112
# 48         Random Forest                 Ensemble  Strategy1      122112
# 52         Random Forest                    Lasso  Strategy1      122112
# 64         Random Forest  Random Forest Regressor  Strategy1      122112
# 56         Random Forest                    Ridge  Strategy1      122112
# 43   Logistic Regression  Random Forest Regressor  Strategy4      137938
# 87               XGBoost              Elastic Net  Strategy4        9954
# 95               XGBoost        XGBoost Regressor  Strategy4       10008
# 91               XGBoost  Random Forest Regressor  Strategy4       10026
# 75               XGBoost                 Ensemble  Strategy4       10017
# 79               XGBoost                    Lasso  Strategy4        9947
# 83               XGBoost                    Ridge  Strategy4        9954
# 47   Logistic Regression        XGBoost Regressor  Strategy4      136678
# 86               XGBoost              Elastic Net  Strategy3        6897
# 82               XGBoost                    Ridge  Strategy3        6896
# 90               XGBoost  Random Forest Regressor  Strategy3        6897
# 74               XGBoost                 Ensemble  Strategy3        6897
# 94               XGBoost        XGBoost Regressor  Strategy3        6894
# 78               XGBoost                    Lasso  Strategy3        6897
# 4               Ensemble                    Lasso  Strategy1      124625
# 8               Ensemble                    Ridge  Strategy1      124625
# 12              Ensemble              Elastic Net  Strategy1      124625
# 16              Ensemble  Random Forest Regressor  Strategy1      124625
# 20              Ensemble        XGBoost Regressor  Strategy1      124625
# 0               Ensemble                 Ensemble  Strategy1      124625
# 25   Logistic Regression                 Ensemble  Strategy2      137137
# 41   Logistic Regression  Random Forest Regressor  Strategy2      127586
# 29   Logistic Regression                    Lasso  Strategy2      142482
# 33   Logistic Regression                    Ridge  Strategy2      138439
# 37   Logistic Regression              Elastic Net  Strategy2      142566
# 45   Logistic Regression        XGBoost Regressor  Strategy2      125689
# 36   Logistic Regression              Elastic Net  Strategy1      122870
# 32   Logistic Regression                    Ridge  Strategy1      122870
# 28   Logistic Regression                    Lasso  Strategy1      122870
# 40   Logistic Regression  Random Forest Regressor  Strategy1      122870
# 24   Logistic Regression                 Ensemble  Strategy1      122870
# 44   Logistic Regression        XGBoost Regressor  Strategy1      122870
# 46   Logistic Regression        XGBoost Regressor  Strategy3       82413
# 34   Logistic Regression                    Ridge  Strategy3       82248
# 42   Logistic Regression  Random Forest Regressor  Strategy3       82819
# 30   Logistic Regression                    Lasso  Strategy3       82376
# 38   Logistic Regression              Elastic Net  Strategy3       81960
# 26   Logistic Regression                 Ensemble  Strategy3       81636
#
#     Clicks     Cost       CTR        CPM         CPC
# 77     160  5731960  0.152526  54.642135   35.824750
# 96     160  5990518  0.208274  77.979199   37.440738
# 108    160  5990518  0.208274  77.979199   37.440738
# 104    160  5990518  0.208274  77.979199   37.440738
# 116    160  5990518  0.208274  77.979199   37.440738
# 100    160  5990518  0.208274  77.979199   37.440738
# 113    160  5788614  0.220095  79.627682   36.178838
# 112    160  5990518  0.208274  77.979199   37.440738
# 89     160  6020706  0.160501  60.395494   37.629413
# 85     160  5774405  0.153019  55.224699   36.090031
# 73     160  5942123  0.154275  57.295012   37.138269
# 97     159  5802320  0.215605  78.679793   36.492579
# 105    159  5767255  0.216332  78.468190   36.272044
# 109    159  5724745  0.216666  78.009743   36.004686
# 117    158  5808658  0.217048  79.794739   36.763658
# 93     158  6046435  0.158767  60.757810   38.268576
# 101    157  5695993  0.213658  77.515487   36.280210
# 81     157  5861943  0.152473  56.929202   37.337217
# 106    157  5345680  0.261828  89.149642   34.048917
# 110    157  5346476  0.261802  89.153996   34.053987
# 98     157  5346476  0.261802  89.153996   34.053987
# 102    157  5346476  0.261802  89.153996   34.053987
# 114    157  5341836  0.261894  89.107827   34.024433
# 118    157  5339690  0.262156  89.161268   34.010764
# 115    151  4721042  0.272740  85.272777   31.265179
# 99     150  4719281  0.270158  84.996866   31.461873
# 103    149  4664094  0.269469  84.350816   31.302644
# 119    148  4724848  0.267510  85.401681   31.924649
# 111    148  4672377  0.267786  84.540367   31.570115
# 107    148  4712867  0.266259  84.786669   31.843696
# 80     144  6249999  0.124552  54.059188   43.402771
# 2      144  3922319  0.326694  88.985866   27.238326
# 72     144  6249999  0.124552  54.059188   43.402771
# 84     144  6249999  0.124552  54.059188   43.402771
# 88     144  6249999  0.124552  54.059188   43.402771
# 92     144  6249999  0.124552  54.059188   43.402771
# 6      144  3922067  0.326701  88.982168   27.236576
# 10     144  3914078  0.326990  88.879559   27.181097
# 22     144  3913804  0.327213  88.933921   27.179194
# 76     144  6249999  0.124552  54.059188   43.402771
# 14     144  3922319  0.326694  88.985866   27.238326
# 18     144  3909215  0.327198  88.825608   27.147326
# 11     139  2798937  0.351774  70.834059   20.136237
# 19     137  2906100  0.346117  73.419736   21.212409
# 5      137  6249991  0.100571  45.880922   45.620372
# 23     137  2937057  0.344178  73.786132   21.438372
# 13     137  6249996  0.101283  46.205567   45.620409
# 57     136  6249997  0.110588  50.821661   45.955860
# 9      136  6249996  0.103775  47.690598   45.955853
# 7      136  2702910  0.346356  68.835889   19.874338
# 15     136  2703565  0.347400  69.060105   19.879154
# 3      136  2834671  0.341151  71.106760   20.843169
# 17     134  6249996  0.108871  50.779123   46.641761
# 61     134  6249996  0.105638  49.271538   46.641761
# 49     134  6249999  0.109520  51.082116   46.641784
# 53     134  6249997  0.105077  49.009590   46.641769
# 65     133  6249996  0.115791  54.413087   46.992451
# 1      133  6249995  0.101312  47.609216   46.992444
# 21     131  6249997  0.107279  51.182916   47.709901
# 69     128  6249999  0.112316  54.841871   48.828117
# 31     122  6202455  0.079764  40.551909   50.839795
# 63     118  1129703  0.708156  67.797095    9.573754
# 51     118  1164960  0.699384  69.046942    9.872542
# 67     118  1183232  0.703595  70.552263   10.027390
# 35     117  6249997  0.078777  42.081571   53.418778
# 71     117  1195477  0.694033  70.914521   10.217752
# 59     116  1139839  0.697912  68.578244    9.826198
# 70     115  1161344  0.814102  82.213224   10.098643
# 55     115  1125332  0.688540  67.377081    9.785496
# 50     115  1162144  0.813756  82.234928   10.105600
# 66     115  1161935  0.813871  82.231776   10.103783
# 54     115  1162144  0.813756  82.234928   10.105600
# 62     115  1162144  0.813756  82.234928   10.105600
# 58     115  1159212  0.814563  82.108797   10.080104
# 39     114  6249986  0.074428  40.804776   54.824439
# 27     113  6249990  0.076396  42.254215   55.309646
# 60     110  6249998  0.090081  51.182505   56.818164
# 68     110  6249998  0.090081  51.182505   56.818164
# 48     110  6249998  0.090081  51.182505   56.818164
# 52     110  6249998  0.090081  51.182505   56.818164
# 64     110  6249998  0.090081  51.182505   56.818164
# 56     110  6249998  0.090081  51.182505   56.818164
# 43     109  6249997  0.079021  45.310190   57.339422
# 87     108   772797  1.084991  77.636829    7.155528
# 95     108   792198  1.079137  79.156475    7.335167
# 91     108   792043  1.077199  78.998903    7.333731
# 75     108   784148  1.078167  78.281721    7.260630
# 79     108   771024  1.085754  77.513220    7.139111
# 83     107   775860  1.074945  77.944545    7.251028
# 47     107  6249996  0.078286  45.727886   58.411178
# 86     101   581952  1.464405  84.377555    5.761901
# 82     101   581932  1.464617  84.386891    5.761703
# 90     101   581952  1.464405  84.377555    5.761901
# 74     101   581952  1.464405  84.377555    5.761901
# 94     101   581818  1.465042  84.394836    5.760574
# 78     101   581952  1.464405  84.377555    5.761901
# 4       99  6249953  0.079438  50.150074   63.130838
# 8       99  6249953  0.079438  50.150074   63.130838
# 12      99  6249953  0.079438  50.150074   63.130838
# 16      99  6249953  0.079438  50.150074   63.130838
# 20      99  6249953  0.079438  50.150074   63.130838
# 0       99  6249953  0.079438  50.150074   63.130838
# 25      96  6249997  0.070003  45.574841   65.104135
# 41      95  6249996  0.074460  48.986535   65.789432
# 29      93  6249982  0.065271  43.865064   67.204108
# 33      92  6249995  0.066455  45.146202   67.934728
# 37      91  6249995  0.063830  43.839310   68.681264
# 45      89  6249998  0.070810  49.725895   70.224697
# 36      68  6249925  0.055343  50.866159   91.910662
# 32      68  6249925  0.055343  50.866159   91.910662
# 28      68  6249925  0.055343  50.866159   91.910662
# 40      68  6249925  0.055343  50.866159   91.910662
# 24      68  6249925  0.055343  50.866159   91.910662
# 44      68  6249925  0.055343  50.866159   91.910662
# 46      54  6249998  0.065524  75.837526  115.740704
# 34      54  6249993  0.065655  75.989605  115.740611
# 42      54  6249989  0.065202  75.465642  115.740537
# 30      53  6249967  0.064339  75.871212  117.923906
# 38      52  6249957  0.063446  76.256186  120.191481
# 26      52  6249987  0.063697  76.559202  120.192058

# %%
pd.options.display.max_rows = 60
