# %%
import pandas as pd
import numpy as np
from functools import reduce
import matplotlib.pyplot as plt
import seaborn as sns
import time

# %matplotlib inline
pd.set_option('display.max_columns', None)
pd.options.mode.chained_assignment = None  # To ignore SettingWithCopyWarning warning

# %% [markdown]
# # Import data

# %%
train = pd.read_csv("train.csv")
validation = pd.read_csv("validation.csv")

# %%
print(train.shape, validation.shape)
# Out:
# (2430981, 25) (303925, 25)

# %% [markdown]
# # Import Predictions

# %%
lr_preds = pd.read_csv("Prediction_csv/lr_pCTR.csv", index_col  = "Unnamed: 0")
rf_preds = pd.read_csv("Prediction_csv/rf_pCTR.csv", index_col  = "Unnamed: 0")
xgb_preds = pd.read_csv("Prediction_csv/xgb_pCTR.csv", index_col  = "Unnamed: 0")
dwane_preds = pd.read_csv("Prediction_csv/click_predictions_narrow.csv")
lasso_preds = pd.read_csv("Prediction_csv/lasso_basebid.csv", index_col  = "Unnamed: 0")
ridge_preds = pd.read_csv("Prediction_csv/ridge_basebid.csv", index_col  = "Unnamed: 0")
elasticnet_preds = pd.read_csv("Prediction_csv/elasticnet_basebid.csv", index_col  = "Unnamed: 0")
rfg_preds = pd.read_csv("Prediction_csv/rfg_basebid.csv", index_col  = "Unnamed: 0")
xgbr_preds = pd.read_csv("Prediction_csv/xgb_basebid.csv", index_col  = "Unnamed: 0")

# %%
rf_preds.head()
# Out:
#                                       bidid  click_proba
# 0  bbcb813b6166538503d8b33a5602d7d72f6019dc     0.060008
# 1  5a07316c49477cb5d9b4d5aa39c27d6c3be7f92d     0.034608
# 2  f6ece71dae81d6b16bfb24ad6dd5611472d4c673     0.042802
# 3  b4d5c57c9b38ff5a12954fa01e11931b4e6bfbbb     0.015992
# 4  0899bf144249458ea9c89188473694bf44c7ca15     0.029209

# %%
base_bid = train.loc[ train["click"] == 1, "payprice"].mean()
avgCTR = train["click"].sum()*100/train.shape[0]

# %%
print("Base bid: {}, avgCTR: {}, ratio: {}".format(base_bid, avgCTR, base_bid/avgCTR))
# Out:
# Base bid: 105.46402677077523, avgCTR: 0.07375623256619447, ratio: 1429.899862037066

# %% [markdown]
# # Strategies

# %%
def Strategy1(sub_pCTR, sub_basebid):
    
    avgCTR = train["click"].sum()*100/train.shape[0]
    base_bid = train.loc[ train["click"] == 1, "payprice"].mean()
    bidprice = (sub_pCTR["click_proba"] * base_bid) / avgCTR
    return bidprice

def Strategy2(sub_pCTR, sub_basebid):
    
    avgCTR = 0.5
    bidprice = (sub_pCTR["click_proba"] * sub_basebid["predicted_payprice"]) / avgCTR
    return bidprice

def Strategy3(sub_pCTR, sub_basebid):
    
    avgCTR = 0.5
    sub_pCTR_ = sub_pCTR.copy()
    sub_pCTR_["click_proba"] = sub_pCTR_["click_proba"].map(lambda x: 0 if x <0.3 else np.exp(x))
    bidprice = (sub_pCTR_["click_proba"] * sub_basebid["predicted_payprice"]) / avgCTR
    return bidprice

def Strategy4(sub_pCTR, sub_basebid):
    
    avgCTR = 0.5
    sub_pCTR_ = sub_pCTR.copy()
    sub_pCTR_["click_proba"] = (sub_pCTR_["click_proba"] + 0.5)**2 - 0.5
    sub_pCTR_.loc[sub_pCTR_["click_proba"] < 0, "click_proba"] = 0
    bidprice = (sub_pCTR_["click_proba"] * sub_basebid["predicted_payprice"]) / avgCTR
    return bidprice

# %% [markdown]
# # Evaluate Results

# %%
budget = 6250*1000

def ValidationDataFrame(submission_pCTR, submission_basebid, strategy):
    
    validation_check = validation[["bidid", "click", "bidprice", "payprice"]]
    validation_check["click_proba"] = submission_pCTR["click_proba"]
    validation_check["basebid_predicted"] = submission_basebid["predicted_payprice"]
    validation_check["bidprice_predicted"] = strategy(submission_pCTR, submission_basebid)
    
    return validation_check


def ValidateStrategy(df):
    
    impressions = 0
    clicks = 0
    cost = 0
    auctions_participated = 0
    balance = budget
    
    for row in df.iterrows():
        
        if cost < budget:
            
            auctions_participated+=1
            
            if (row[1]["bidprice_predicted"] >= row[1]["payprice"]):
                
                if (balance > row[1]["bidprice_predicted"]):
                    
                    impressions+=1
                    clicks+=row[1]["click"]
                    cost+=row[1]["payprice"]
                    balance-=row[1]["payprice"]
                else:
                    pass
    
        else:
            break
    
    # Metrics
    ctr = clicks*100/impressions
    cpm = cost/(impressions*1000)
    cpc = cost/clicks
    
    print("Strategy statistics:")
    print("Auctions participated: {} | Impressions: {} | Clicks: {} | Cost: {} | CTR: {} | CPM: {} | CPC: {}".format(auctions_participated, \
                                                                                                                     impressions, clicks, cost,\
                                                                                                                     ctr, cpm, cpc))
    print("\n")
            
    return impressions, clicks, cost, auctions_participated, ctr, cpm, cpc

# def StrategyResults(impressions, clicks, cost):
#     ctr = clicks*100/impressions
#     spend = cost
#     cpm = cost/(impressions*1000)
#     if clicks > 0:
#         cpc = cost/clicks
#     else:
#         cpc = np.inf
        
#     print("Strategy results")
#     print("CTR: {} | Clicks: {} | Spend: {} | CPM: {} | CPC: {}".format(ctr, clicks, spend, cpm, cpc))
#     print("\n")
        
#     return ctr, clicks, spend, cpm, cpc

# %%
pCTR_preds = [lr_preds, rf_preds, xgb_preds, dwane_preds]
basebid_preds = [lasso_preds, ridge_preds, elasticnet_preds, rfg_preds, xgbr_preds]
pCTR_model_names = ["Logistic Regression", "Random Forest", "XGBoost", "Dwane Model"]
basebid_model_names = ["Lasso", "Ridge", "Elastic Net", "Random Forest Regressor", "XGBoost Regressor"]
results = pd.DataFrame(columns = ["pCTR_model", "basebid_model", "Strategy", "Impressions", "Clicks", "Cost", "CTR", "CPM", "CPC"])
i=0
j=0
k=0

start = time.time()

for pCTR_pred in pCTR_preds:
    for basebid_pred in basebid_preds:
        
        # Strategy 1
        validation_check = ValidationDataFrame(pCTR_pred, basebid_pred, Strategy1)
        print("\033[1m pCTR model: {} \033[0m, \033[1m basebid model: {} \033[0m, \033[1m Strategy 1 \033[0m ".format(pCTR_model_names[i], basebid_model_names[j]))
        impressions, clicks, cost, auctions_participated, ctr, cpm, cpc = ValidateStrategy(validation_check)
        results.loc[k] = [pCTR_model_names[i], basebid_model_names[j], "Strategy1", impressions, clicks, cost, ctr, cpm, cpc]
        k+=1
        
        # Strategy 2
        validation_check = ValidationDataFrame(pCTR_pred, basebid_pred, Strategy2)
        print("\033[1m pCTR model: {} \033[0m, \033[1m basebid model: {} \033[0m, \033[1m Strategy 2 \033[0m ".format(pCTR_model_names[i], basebid_model_names[j]))
        impressions, clicks, cost, auctions_participated, ctr, cpm, cpc = ValidateStrategy(validation_check)
        results.loc[k] = [pCTR_model_names[i], basebid_model_names[j], "Strategy2", impressions, clicks, cost, ctr, cpm, cpc]
        k+=1
        
        # Strategy 3
        validation_check = ValidationDataFrame(pCTR_pred, basebid_pred, Strategy3)
        print("\033[1m pCTR model: {} \033[0m, \033[1m basebid model: {} \033[0m, \033[1m Strategy 3 \033[0m ".format(pCTR_model_names[i], basebid_model_names[j]))
        impressions, clicks, cost, auctions_participated, ctr, cpm, cpc= ValidateStrategy(validation_check)
        results.loc[k] = [pCTR_model_names[i], basebid_model_names[j], "Strategy3", impressions, clicks, cost, ctr, cpm, cpc]
        k+=1
        
        # Strategy 4
        validation_check = ValidationDataFrame(pCTR_pred, basebid_pred, Strategy4)
        print("\033[1m pCTR model: {} \033[0m, \033[1m basebid model: {} \033[0m, \033[1m Strategy 4 \033[0m ".format(pCTR_model_names[i], basebid_model_names[j]))
        impressions, clicks, cost, auctions_participated, ctr, cpm, cpc= ValidateStrategy(validation_check)
        results.loc[k] = [pCTR_model_names[i], basebid_model_names[j], "Strategy4", impressions, clicks, cost, ctr, cpm, cpc]
        k+=1
        
        j+=1
        
        
    j=0    
    i+=1
    
end = time.time()
print("Total time: {} mins".format((end-start)/60))
# Out:
#  pCTR model: Logistic Regression ,  basebid model: Lasso ,  Strategy 1
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 79694 | Clicks: 51 | Cost: 6249493 | CTR: 0.06399478003362863 | CPM: 0.07841861369739253 | CPC: 122539.07843137255
#
#
#  pCTR model: Logistic Regression ,  basebid model: Lasso ,  Strategy 2
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 152272 | Clicks: 109 | Cost: 5915338 | CTR: 0.0715824314384785 | CPM: 0.03884718135967217 | CPC: 54269.15596330275
#
#
#  pCTR model: Logistic Regression ,  basebid model: Lasso ,  Strategy 3
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 83573 | Clicks: 53 | Cost: 6249940 | CTR: 0.0634176109509052 | CPM: 0.07478420063896235 | CPC: 117923.39622641509
#
#
#  pCTR model: Logistic Regression ,  basebid model: Lasso ,  Strategy 4
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 134661 | Clicks: 107 | Cost: 4850487 | CTR: 0.07945878910746244 | CPM: 0.03601998351415778 | CPC: 45331.654205607476
#
#
#  pCTR model: Logistic Regression ,  basebid model: Ridge ,  Strategy 1
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 79694 | Clicks: 51 | Cost: 6249493 | CTR: 0.06399478003362863 | CPM: 0.07841861369739253 | CPC: 122539.07843137255
#
#
#  pCTR model: Logistic Regression ,  basebid model: Ridge ,  Strategy 2
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 152124 | Clicks: 112 | Cost: 6075859 | CTR: 0.07362414872078042 | CPM: 0.03994017380557966 | CPC: 54248.74107142857
#
#
#  pCTR model: Logistic Regression ,  basebid model: Ridge ,  Strategy 3
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 83392 | Clicks: 53 | Cost: 6249998 | CTR: 0.0635552570990023 | CPM: 0.07494721316193399 | CPC: 117924.49056603774
#
#
#  pCTR model: Logistic Regression ,  basebid model: Ridge ,  Strategy 4
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 134501 | Clicks: 111 | Cost: 5060465 | CTR: 0.08252726745526055 | CPM: 0.03762399536062929 | CPC: 45589.77477477478
#
#
#  pCTR model: Logistic Regression ,  basebid model: Elastic Net ,  Strategy 1
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 79694 | Clicks: 51 | Cost: 6249493 | CTR: 0.06399478003362863 | CPM: 0.07841861369739253 | CPC: 122539.07843137255
#
#
#  pCTR model: Logistic Regression ,  basebid model: Elastic Net ,  Strategy 2
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 151356 | Clicks: 103 | Cost: 5863568 | CTR: 0.06805148127593223 | CPM: 0.03874024154972383 | CPC: 56927.844660194176
#
#
#  pCTR model: Logistic Regression ,  basebid model: Elastic Net ,  Strategy 3
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 
#
#
#  pCTR model: Dwane Model ,  basebid model: Elastic Net ,  Strategy 1
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 75369 | Clicks: 142 | Cost: 6249963 | CTR: 0.18840637397338428 | CPM: 0.08292484973928273 | CPC: 44013.82394366197
#
#
#  pCTR model: Dwane Model ,  basebid model: Elastic Net ,  Strategy 2
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 45223 | Clicks: 118 | Cost: 2756315 | CTR: 0.2609291732083232 | CPM: 0.06094940627556774 | CPC: 23358.601694915254
#
#
#  pCTR model: Dwane Model ,  basebid model: Elastic Net ,  Strategy 3
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 59306 | Clicks: 154 | Cost: 5192201 | CTR: 0.25967018514146967 | CPM: 0.08754933733517688 | CPC: 33715.59090909091
#
#
#  pCTR model: Dwane Model ,  basebid model: Elastic Net ,  Strategy 4
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 43633 | Clicks: 134 | Cost: 3300668 | CTR: 0.30710700616505854 | CPM: 0.0756461393899113 | CPC: 24631.850746268658
#
#
#  pCTR model: Dwane Model ,  basebid model: Random Forest Regressor ,  Strategy 1
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 75369 | Clicks: 142 | Cost: 6249963 | CTR: 0.18840637397338428 | CPM: 0.08292484973928273 | CPC: 44013.82394366197
#
#
#  pCTR model: Dwane Model ,  basebid model: Random Forest Regressor ,  Strategy 2
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 45549 | Clicks: 125 | Cost: 3033390 | CTR: 0.2744297350106479 | CPM: 0.06659619311071593 | CPC: 24267.12
#
#
#  pCTR model: Dwane Model ,  basebid model: Random Forest Regressor ,  Strategy 3
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 59124 | Clicks: 156 | Cost: 5172717 | CTR: 0.2638522427440633 | CPM: 0.0874892936878425 | CPC: 33158.442307692305
#
#
#  pCTR model: Dwane Model ,  basebid model: Random Forest Regressor ,  Strategy 4
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 43894 | Clicks: 138 | Cost: 3412317 | CTR: 0.3143937668018408 | CPM: 0.07773994167767805 | CPC: 24726.934782608696
#
#
#  pCTR model: Dwane Model ,  basebid model: XGBoost Regressor ,  Strategy 1
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 75369 | Clicks: 142 | Cost: 6249963 | CTR: 0.18840637397338428 | CPM: 0.08292484973928273 | CPC: 44013.82394366197
#
#
#  pCTR model: Dwane Model ,  basebid model: XGBoost Regressor ,  Strategy 2
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 45916 | Clicks: 118 | Cost: 3086768 | CTR: 0.25699102709295235 | CPM: 0.06722641345064902 | CPC: 26159.050847457627
#
#
#  pCTR model: Dwane Model ,  basebid model: XGBoost Regressor ,  Strategy 3
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 59144 | Clicks: 155 | Cost: 5187546 | CTR: 0.26207223048829975 | CPM: 0.08771043554713918 | CPC: 33468.03870967742
#
#
#  pCTR model: Dwane Model ,  basebid model: XGBoost Regressor ,  Strategy 4
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 44003 | Clicks: 135 | Cost: 3442828 | CTR: 0.30679726382292116 | CPM: 0.07824075631206963 | CPC: 25502.42962962963
#
#
# Total time: 33.53271120389302 mins

# %%
results
# Out:
#              pCTR_model            basebid_model   Strategy Impressions  \
# 0   Logistic Regression                    Lasso  Strategy1       79694
# 1   Logistic Regression                    Lasso  Strategy2      152272
# 2   Logistic Regression                    Lasso  Strategy3       83573
# 3   Logistic Regression                    Lasso  Strategy4      134661
# 4   Logistic Regression                    Ridge  Strategy1       79694
# 5   Logistic Regression                    Ridge  Strategy2      152124
# 6   Logistic Regression                    Ridge  Strategy3       83392
# 7   Logistic Regression                    Ridge  Strategy4      134501
# 8   Logistic Regression              Elastic Net  Strategy1       79694
# 9   Logistic Regression              Elastic Net  Strategy2      151356
# 10  Logistic Regression              Elastic Net  Strategy3       83135
# 11  Logistic Regression              Elastic Net  Strategy4      133974
# 12  Logistic Regression  Random Forest Regressor  Strategy1       79694
# 13  Logistic Regression  Random Forest Regressor  Strategy2      141878
# 14  Logistic Regression  Random Forest Regressor  Strategy3       83825
# 15  Logistic Regression  Random Forest Regressor  Strategy4      124798
# 16  Logistic Regression        XGBoost Regressor  Strategy1       79694
# 17  Logistic Regression        XGBoost Regressor  Strategy2      143901
# 18  Logistic Regression        XGBoost Regressor  Strategy3       83368
# 19  Logistic Regression        XGBoost Regressor  Strategy4      125198
# 20        Random Forest                    Lasso  Strategy1      110570
# 21        Random Forest                    Lasso  Strategy2       22504
# 22        Random Forest                    Lasso  Strategy3       11728
# 23        Random Forest                    Lasso  Strategy4        6390
# 24        Random Forest                    Ridge  Strategy1      110570
# 25        Random Forest                    Ridge  Strategy2       21238
# 26        Random Forest                    Ridge  Strategy3       11685
# 27        Random Forest                    Ridge  Strategy4        6446
# 28        Random Forest              Elastic Net  Strategy1      110570
# 29        Random Forest              Elastic Net  Strategy2       22158
# ..                  ...                      ...        ...         ...
# 50              XGBoost              Elastic Net  Strategy3        6850
# 51              XGBoost              Elastic Net  Strategy4        3749
# 52              XGBoost  Random Forest Regressor  Strategy1       92851
# 53              XGBoost  Random Forest Regressor  Strategy2        9263
# 54              XGBoost  Random Forest Regressor  Strategy3        6854
# 55              XGBoost  Random Forest Regressor  Strategy4        3767
# 56              XGBoost        XGBoost Regressor  Strategy1       92851
# 57              XGBoost        XGBoost Regressor  Strategy2        9309
# 58              XGBoost        XGBoost Regressor  Strategy3        6840
# 59              XGBoost        XGBoost Regressor  Strategy4        3745
# 60          Dwane Model                    Lasso  Strategy1       75369
# 61          Dwane Model                    Lasso  Strategy2       45474
# 62          Dwane Model                    Lasso  Strategy3       59180
# 63          Dwane Model                    Lasso  Strategy4       43596
# 64          Dwane Model                    Ridge  Strategy1       75369
# 65          Dwane Model                    Ridge  Strategy2       45734
# 66          Dwane Model                    Ridge  Strategy3       59202
# 67          Dwane Model                    Ridge  Strategy4       43914
# 68          Dwane Model              Elastic Net  Strategy1       75369
# 69          Dwane Model              Elastic Net  Strategy2       45223
# 70          Dwane Model              Elastic Net  Strategy3       59306
# 71          Dwane Model              Elastic Net  Strategy4       43633
# 72          Dwane Model  Random Forest Regressor  Strategy1       75369
# 73          Dwane Model  Random Forest Regressor  Strategy2       45549
# 74          Dwane Model  Random Forest Regressor  Strategy3       59124
# 75          Dwane Model  Random Forest Regressor  Strategy4       43894
# 76          Dwane Model        XGBoost Regressor  Strategy1       75369
# 77          Dwane Model        XGBoost Regressor  Strategy2       45916
# 78          Dwane Model        XGBoost Regressor  Strategy3       59144
# 79          Dwane Model        XGBoost Regressor  Strategy4       44003
#
#    Clicks     Cost       CTR       CPM            CPC
# 0      51  6249493  0.063995  0.078419  122539.078431
# 1     109  5915338  0.071582  0.038847   54269.155963
# 2      53  6249940  0.063418  0.074784  117923.396226
# 3     107  4850487  0.079459  0.036020   45331.654206
# 4      51  6249493  0.063995  0.078419  122539.078431
# 5     112  6075859  0.073624  0.039940   54248.741071
# 6      53  6249998  0.063555  0.074947  117924.490566
# 7     111  5060465  0.082527  0.037624   45589.774775
# 8      51  6249493  0.063995  0.078419  122539.078431
# 9     103  5863568  0.068051  0.038740   56927.844660
# 10     53  6249958  0.063752  0.075178  117923.735849
# 11    107  4845326  0.079866  0.036166   45283.420561
# 12     51  6249493  0.063995  0.078419  122539.078431
# 13    113  6094286  0.079646  0.042954   53931.734513
# 14     54  6249988  0.064420  0.074560  115740.518519
# 15    111  5045874  0.088944  0.040432   45458.324324
# 16     51  6249493  0.063995  0.078419  122539.078431
# 17    108  6249989  0.075052  0.043433   57870.268519
# 18     54  6249995  0.064773  0.074969  115740.648148
# 19    104  5084613  0.083068  0.040613   48890.509615
# 20     91  6249994  0.082301  0.056525   68681.252747
# 21     59   460427  0.262176  0.020460    7803.847458
# 22    103   898586  0.878240  0.076619    8724.135922
# 23     54   269125  0.845070  0.042117    4983.796296
# 24     91  6249994  0.082301  0.056525   68681.252747
# 25     67   462499  0.315472  0.021777    6902.970149
# 26    108   900974  0.924262  0.077105    8342.351852
# 27     59   286291  0.915296  0.044414    4852.389831
# 28     91  6249994  0.082301  0.056525   68681.252747
# 29     59   452296  0.266270  0.020412    7666.033898
# ..    ...      ...       ...       ...            ...
# 50     95   555583  1.386861  0.081107    5848.242105
# 51     84   187778  2.240597  0.050087    2235.452381
# 52    149  4504986  0.160472  0.048518   30234.805369
# 53     78   270546  0.842060  0.029207    3468.538462
# 54     96   557860  1.400642  0.081392    5811.041667
# 55     85   202238  2.256437  0.053687    2379.270588
# 56    149  4504986  0.160472  0.048518   30234.805369
# 57     75   271402  0.805672  0.029155    3618.693333
# 58     96   555511  1.403509  0.081215    5786.572917
# 59     84   200891  2.242991  0.053642    2391.559524
# 60    142  6249963  0.188406  0.082925   44013.823944
# 61    118  2745549  0.259489  0.060376   23267.364407
# 62    153  5160853  0.258533  0.087206   33731.065359
# 63    133  3261347  0.305074  0.074808   24521.406015
# 64    142  6249963  0.188406  0.082925   44013.823944
# 65    119  2899728  0.260200  0.063404   24367.462185
# 66    156  5182149  0.263505  0.087533   33218.903846
# 67    138  3373358  0.314251  0.076817   24444.623188
# 68    142  6249963  0.188406  0.082925   44013.823944
# 69    118  2756315  0.260929  0.060949   23358.601695
# 70    154  5192201  0.259670  0.087549   33715.590909
# 71    134  3300668  0.307107  0.075646   24631.850746
# 72    142  6249963  0.188406  0.082925   44013.823944
# 73    125  3033390  0.274430  0.066596   24267.120000
# 74    156  5172717  0.263852  0.087489   33158.442308
# 75    138  3412317  0.314394  0.077740   24726.934783
# 76    142  6249963  0.188406  0.082925   44013.823944
# 77    118  3086768  0.256991  0.067226   26159.050847
# 78    155  5187546  0.262072  0.087710   33468.038710
# 79    135  3442828  0.306797  0.078241   25502.429630
#
# [80 rows x 9 columns]

# %%
results.to_csv("ValidationSet_Eavaluation_Results.csv")

# %%
results.sort_values(by = "Clicks", ascending = False)
# Out:
#              pCTR_model            basebid_model   Strategy Impressions  \
# 66          Dwane Model                    Ridge  Strategy3       59202
# 74          Dwane Model  Random Forest Regressor  Strategy3       59124
# 78          Dwane Model        XGBoost Regressor  Strategy3       59144
# 70          Dwane Model              Elastic Net  Strategy3       59306
# 62          Dwane Model                    Lasso  Strategy3       59180
# 40              XGBoost                    Lasso  Strategy1       92851
# 52              XGBoost  Random Forest Regressor  Strategy1       92851
# 56              XGBoost        XGBoost Regressor  Strategy1       92851
# 48              XGBoost              Elastic Net  Strategy1       92851
# 44              XGBoost                    Ridge  Strategy1       92851
# 64          Dwane Model                    Ridge  Strategy1       75369
# 72          Dwane Model  Random Forest Regressor  Strategy1       75369
# 60          Dwane Model                    Lasso  Strategy1       75369
# 76          Dwane Model        XGBoost Regressor  Strategy1       75369
# 68          Dwane Model              Elastic Net  Strategy1       75369
# 67          Dwane Model                    Ridge  Strategy4       43914
# 75          Dwane Model  Random Forest Regressor  Strategy4       43894
# 79          Dwane Model        XGBoost Regressor  Strategy4       44003
# 71          Dwane Model              Elastic Net  Strategy4       43633
# 63          Dwane Model                    Lasso  Strategy4       43596
# 73          Dwane Model  Random Forest Regressor  Strategy2       45549
# 65          Dwane Model                    Ridge  Strategy2       45734
# 69          Dwane Model              Elastic Net  Strategy2       45223
# 77          Dwane Model        XGBoost Regressor  Strategy2       45916
# 61          Dwane Model                    Lasso  Strategy2       45474
# 13  Logistic Regression  Random Forest Regressor  Strategy2      141878
# 5   Logistic Regression                    Ridge  Strategy2      152124
# 15  Logistic Regression  Random Forest Regressor  Strategy4      124798
# 7   Logistic Regression                    Ridge  Strategy4      134501
# 1   Logistic Regression                    Lasso  Strategy2      152272
# ..                  ...                      ...        ...         ...
# 55              XGBoost  Random Forest Regressor  Strategy4        3767
# 59              XGBoost        XGBoost Regressor  Strategy4        3745
# 47              XGBoost                    Ridge  Strategy4        3871
# 51              XGBoost              Elastic Net  Strategy4        3749
# 43              XGBoost                    Lasso  Strategy4        3728
# 53              XGBoost  Random Forest Regressor  Strategy2        9263
# 45              XGBoost                    Ridge  Strategy2        9622
# 57              XGBoost        XGBoost Regressor  Strategy2        9309
# 49              XGBoost              Elastic Net  Strategy2        9738
# 41              XGBoost                    Lasso  Strategy2        9724
# 25        Random Forest                    Ridge  Strategy2       21238
# 35        Random Forest  Random Forest Regressor  Strategy4        6404
# 37        Random Forest        XGBoost Regressor  Strategy2       20309
# 29        Random Forest              Elastic Net  Strategy2       22158
# 27        Random Forest                    Ridge  Strategy4        6446
# 21        Random Forest                    Lasso  Strategy2       22504
# 33        Random Forest  Random Forest Regressor  Strategy2       20141
# 39        Random Forest        XGBoost Regressor  Strategy4        6363
# 18  Logistic Regression        XGBoost Regressor  Strategy3       83368
# 14  Logistic Regression  Random Forest Regressor  Strategy3       83825
# 31        Random Forest              Elastic Net  Strategy4        6436
# 23        Random Forest                    Lasso  Strategy4        6390
# 10  Logistic Regression              Elastic Net  Strategy3       83135
# 6   Logistic Regression                    Ridge  Strategy3       83392
# 2   Logistic Regression                    Lasso  Strategy3       83573
# 8   Logistic Regression              Elastic Net  Strategy1       79694
# 12  Logistic Regression  Random Forest Regressor  Strategy1       79694
# 16  Logistic Regression        XGBoost Regressor  Strategy1       79694
# 4   Logistic Regression                    Ridge  Strategy1       79694
# 0   Logistic Regression                    Lasso  Strategy1       79694
#
#    Clicks     Cost       CTR       CPM            CPC
# 66    156  5182149  0.263505  0.087533   33218.903846
# 74    156  5172717  0.263852  0.087489   33158.442308
# 78    155  5187546  0.262072  0.087710   33468.038710
# 70    154  5192201  0.259670  0.087549   33715.590909
