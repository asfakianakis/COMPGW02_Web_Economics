# %%
import pandas as pd
import numpy as np
from functools import reduce
import matplotlib.pyplot as plt
import seaborn as sns
import time

# %matplotlib inline
pd.set_option('display.max_columns', None)
pd.options.mode.chained_assignment = None  # To ignore SettingWithCopyWarning warning

# %% [markdown]
# # Import data

# %%
train = pd.read_csv("Prediction_csv/train.csv")
validation = pd.read_csv("Prediction_csv/validation.csv")

# %%
print(train.shape, validation.shape)
# Out:
# (2430981, 25) (303925, 25)

# %% [markdown]
# # Import Predictions

# %%
lr_preds = pd.read_csv("Prediction_csv/lr_pCTR.csv", index_col  = "Unnamed: 0")
rf_preds = pd.read_csv("Prediction_csv/rf_pCTR.csv", index_col  = "Unnamed: 0")
xgb_preds = pd.read_csv("Prediction_csv/xgb_pCTR.csv", index_col  = "Unnamed: 0")
dwane_preds = pd.read_csv("Prediction_csv/click_predictions_narrow.csv")
lasso_preds = pd.read_csv("Prediction_csv/lasso_basebid.csv", index_col  = "Unnamed: 0")
ridge_preds = pd.read_csv("Prediction_csv/ridge_basebid.csv", index_col  = "Unnamed: 0")
elasticnet_preds = pd.read_csv("Prediction_csv/elasticnet_basebid.csv", index_col  = "Unnamed: 0")
rfg_preds = pd.read_csv("Prediction_csv/rfg_basebid.csv", index_col  = "Unnamed: 0")
xgbr_preds = pd.read_csv("Prediction_csv/xgb_basebid.csv", index_col  = "Unnamed: 0")

# %%
rf_preds.head()
# Out:
#                                       bidid  click_proba
# 0  bbcb813b6166538503d8b33a5602d7d72f6019dc     0.060008
# 1  5a07316c49477cb5d9b4d5aa39c27d6c3be7f92d     0.034608
# 2  f6ece71dae81d6b16bfb24ad6dd5611472d4c673     0.042802
# 3  b4d5c57c9b38ff5a12954fa01e11931b4e6bfbbb     0.015992
# 4  0899bf144249458ea9c89188473694bf44c7ca15     0.029209

# %%
base_bid = train.loc[ train["click"] == 1, "payprice"].mean()
avgCTR = train["click"].sum()*100/train.shape[0]

# %%
print("Base bid: {}, avgCTR: {}, ratio: {}".format(base_bid, avgCTR, base_bid/avgCTR))
# Out:
# Base bid: 105.46402677077523, avgCTR: 0.07375623256619447, ratio: 1429.899862037066

# %% [markdown]
# # Strategies

# %%
def Strategy1(sub_pCTR, sub_basebid):
    
    avgCTR = train["click"].sum()*100/train.shape[0]
    base_bid = train.loc[ train["click"] == 1, "payprice"].mean()
    bidprice = (sub_pCTR["click_proba"] * base_bid) / avgCTR
    return bidprice

def Strategy2(sub_pCTR, sub_basebid):
    
    avgCTR = 0.5
    bidprice = (sub_pCTR["click_proba"] * sub_basebid["predicted_payprice"]) / avgCTR
    return bidprice

def Strategy3(sub_pCTR, sub_basebid):
    
    avgCTR = 0.5
    sub_pCTR_ = sub_pCTR.copy()
    sub_pCTR_["click_proba"] = sub_pCTR_["click_proba"].map(lambda x: 0 if x <0.3 else np.exp(x))
    bidprice = (sub_pCTR_["click_proba"] * sub_basebid["predicted_payprice"]) / avgCTR
    return bidprice

def Strategy4(sub_pCTR, sub_basebid):
    
    avgCTR = 0.5
    sub_pCTR_ = sub_pCTR.copy()
    sub_pCTR_["click_proba"] = (sub_pCTR_["click_proba"] + 0.5)**2 - 0.5
    sub_pCTR_.loc[sub_pCTR_["click_proba"] < 0, "click_proba"] = 0
    bidprice = (sub_pCTR_["click_proba"] * sub_basebid["predicted_payprice"]) / avgCTR
    return bidprice

# %% [markdown]
# # Evaluate Results

# %%
budget = 6250*1000

def ValidationDataFrame(submission_pCTR, submission_basebid, strategy):
    
    validation_check = validation[["bidid", "click", "bidprice", "payprice"]]
    validation_check["click_proba"] = submission_pCTR["click_proba"]
    validation_check["basebid_predicted"] = submission_basebid["predicted_payprice"]
    validation_check["bidprice_predicted"] = strategy(submission_pCTR, submission_basebid)
    
    return validation_check


def ValidateStrategy(df):
    
    impressions = 0
    clicks = 0
    cost = 0
    auctions_participated = 0
    balance = budget
    
    for row in df.iterrows():
        
        if cost <= budget:
            
            auctions_participated+=1
            
            if (row[1]["bidprice_predicted"] >= row[1]["payprice"]):
                
                if (balance > row[1]["bidprice_predicted"]):
                    
                    impressions+=1
                    clicks+=row[1]["click"]
                    cost+=row[1]["payprice"]
                    balance-=row[1]["payprice"]
                else:
                    pass
    
        else:
            break
    
    # Metrics
    ctr = clicks*100/impressions
    cpm = cost/(impressions*1000)
    cpc = cost/clicks
    
    print("Strategy statistics:")
    print("Auctions participated: {} | Impressions: {} | Clicks: {} | Cost: {} | CTR: {} | CPM: {} | CPC: {}".format(auctions_participated, \
                                                                                                                     impressions, clicks, cost,\
                                                                                                                     ctr, cpm, cpc))
    print("\n")
            
    return impressions, clicks, cost, auctions_participated, ctr, cpm, cpc

# def StrategyResults(impressions, clicks, cost):
#     ctr = clicks*100/impressions
#     spend = cost
#     cpm = cost/(impressions*1000)
#     if clicks > 0:
#         cpc = cost/clicks
#     else:
#         cpc = np.inf
        
#     print("Strategy results")
#     print("CTR: {} | Clicks: {} | Spend: {} | CPM: {} | CPC: {}".format(ctr, clicks, spend, cpm, cpc))
#     print("\n")
        
#     return ctr, clicks, spend, cpm, cpc

# %%
pCTR_preds = [lr_preds, rf_preds, xgb_preds, dwane_preds]
basebid_preds = [lasso_preds, ridge_preds, elasticnet_preds, rfg_preds, xgbr_preds]
pCTR_model_names = ["Logistic Regression", "Random Forest", "XGBoost", "Dwane Model"]
basebid_model_names = ["Lasso", "Ridge", "Elastic Net", "Random Forest Regressor", "XGBoost Regressor"]
results = pd.DataFrame(columns = ["pCTR_model", "basebid_model", "Strategy", "Impressions", "Clicks", "Cost", "CTR", "CPM", "CPC"])
i=0
j=0
k=0

start = time.time()

for pCTR_pred in pCTR_preds:
    for basebid_pred in basebid_preds:
        
        # Strategy 1
        validation_check = ValidationDataFrame(pCTR_pred, basebid_pred, Strategy1)
        print("\033[1m pCTR model: {} \033[0m, \033[1m basebid model: {} \033[0m, \033[1m Strategy 1 \033[0m ".format(pCTR_model_names[i], basebid_model_names[j]))
        impressions, clicks, cost, auctions_participated, ctr, cpm, cpc = ValidateStrategy(validation_check)
        results.loc[k] = [pCTR_model_names[i], basebid_model_names[j], "Strategy1", impressions, clicks, cost, ctr, cpm, cpc]
        k+=1
        
        # Strategy 2
        validation_check = ValidationDataFrame(pCTR_pred, basebid_pred, Strategy2)
        print("\033[1m pCTR model: {} \033[0m, \033[1m basebid model: {} \033[0m, \033[1m Strategy 2 \033[0m ".format(pCTR_model_names[i], basebid_model_names[j]))
        impressions, clicks, cost, auctions_participated, ctr, cpm, cpc = ValidateStrategy(validation_check)
        results.loc[k] = [pCTR_model_names[i], basebid_model_names[j], "Strategy2", impressions, clicks, cost, ctr, cpm, cpc]
        k+=1
        
        # Strategy 3
        validation_check = ValidationDataFrame(pCTR_pred, basebid_pred, Strategy3)
        print("\033[1m pCTR model: {} \033[0m, \033[1m basebid model: {} \033[0m, \033[1m Strategy 3 \033[0m ".format(pCTR_model_names[i], basebid_model_names[j]))
        impressions, clicks, cost, auctions_participated, ctr, cpm, cpc= ValidateStrategy(validation_check)
        results.loc[k] = [pCTR_model_names[i], basebid_model_names[j], "Strategy3", impressions, clicks, cost, ctr, cpm, cpc]
        k+=1
        
        # Strategy 4
        validation_check = ValidationDataFrame(pCTR_pred, basebid_pred, Strategy4)
        print("\033[1m pCTR model: {} \033[0m, \033[1m basebid model: {} \033[0m, \033[1m Strategy 4 \033[0m ".format(pCTR_model_names[i], basebid_model_names[j]))
        impressions, clicks, cost, auctions_participated, ctr, cpm, cpc= ValidateStrategy(validation_check)
        results.loc[k] = [pCTR_model_names[i], basebid_model_names[j], "Strategy4", impressions, clicks, cost, ctr, cpm, cpc]
        k+=1
        
        j+=1
        
        
    j=0    
    i+=1
    
end = time.time()
print("Total time: {} mins".format((end-start)/60))
# Out:
#  pCTR model: Logistic Regression ,  basebid model: Lasso ,  Strategy 1
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 79694 | Clicks: 51 | Cost: 6249493 | CTR: 0.06399478003362863 | CPM: 0.07841861369739253 | CPC: 122539.07843137255
#
#
#  pCTR model: Logistic Regression ,  basebid model: Lasso ,  Strategy 2
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 151952 | Clicks: 109 | Cost: 5901069 | CTR: 0.07173317889859956 | CPM: 0.03883508607981468 | CPC: 54138.247706422015
#
#
#  pCTR model: Logistic Regression ,  basebid model: Lasso ,  Strategy 3
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 83574 | Clicks: 53 | Cost: 6249942 | CTR: 0.06341685213104555 | CPM: 0.0747833297437002 | CPC: 117923.43396226416
#
#
#  pCTR model: Logistic Regression ,  basebid model: Lasso ,  Strategy 4
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 134072 | Clicks: 107 | Cost: 4821431 | CTR: 0.07980786443105198 | CPM: 0.03596150575810012 | CPC: 45060.102803738315
#
#
#  pCTR model: Logistic Regression ,  basebid model: Ridge ,  Strategy 1
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 79694 | Clicks: 51 | Cost: 6249493 | CTR: 0.06399478003362863 | CPM: 0.07841861369739253 | CPC: 122539.07843137255
#
#
#  pCTR model: Logistic Regression ,  basebid model: Ridge ,  Strategy 2
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 152217 | Clicks: 112 | Cost: 6083821 | CTR: 0.07357916658454706 | CPM: 0.03996807846692551 | CPC: 54319.830357142855
#
#
#  pCTR model: Logistic Regression ,  basebid model: Ridge ,  Strategy 3
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 83387 | Clicks: 53 | Cost: 6249997 | CTR: 0.06355906796023361 | CPM: 0.07495169510835022 | CPC: 117924.47169811321
#
#
#  pCTR model: Logistic Regression ,  basebid model: Ridge ,  Strategy 4
# Strategy statistics:
# Auctions participated: 303925 | Impressions:
#
#
#  pCTR model: Dwane Model ,  basebid model: Lasso ,  Strategy 3
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 59182 | Clicks: 153 | Cost: 5161436 | CTR: 0.2585245513838667 | CPM: 0.08721293636578689 | CPC: 33734.875816993466
#
#
#  pCTR model: Dwane Model ,  basebid model: Lasso ,  Strategy 4
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 43622 | Clicks: 133 | Cost: 3262007 | CTR: 0.30489202695887396 | CPM: 0.07477894181834854 | CPC: 24526.36842105263
#
#
#  pCTR model: Dwane Model ,  basebid model: Ridge ,  Strategy 1
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 75369 | Clicks: 142 | Cost: 6249963 | CTR: 0.18840637397338428 | CPM: 0.08292484973928273 | CPC: 44013.82394366197
#
#
#  pCTR model: Dwane Model ,  basebid model: Ridge ,  Strategy 2
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 45746 | Clicks: 119 | Cost: 2904922 | CTR: 0.2601320334018275 | CPM: 0.06350111485157173 | CPC: 24411.10924369748
#
#
#  pCTR model: Dwane Model ,  basebid model: Ridge ,  Strategy 3
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 59200 | Clicks: 156 | Cost: 5182384 | CTR: 0.2635135135135135 | CPM: 0.08754027027027027 | CPC: 33220.41025641026
#
#
#  pCTR model: Dwane Model ,  basebid model: Ridge ,  Strategy 4
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 43911 | Clicks: 138 | Cost: 3374051 | CTR: 0.31427205028352806 | CPM: 0.07683840040081073 | CPC: 24449.644927536232
#
#
#  pCTR model: Dwane Model ,  basebid model: Elastic Net ,  Strategy 1
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 75369 | Clicks: 142 | Cost: 6249963 | CTR: 0.18840637397338428 | CPM: 0.08292484973928273 | CPC: 44013.82394366197
#
#
#  pCTR model: Dwane Model ,  basebid model: Elastic Net ,  Strategy 2
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 45503 | Clicks: 119 | Cost: 2810481 | CTR: 0.2615212183812056 | CPM: 0.061764740786321784 | CPC: 23617.48739495798
#
#
#  pCTR model: Dwane Model ,  basebid model: Elastic Net ,  Strategy 3
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 59326 | Clicks: 155 | Cost: 5197643 | CTR: 0.2612682466372248 | CPM: 0.08761155311330614 | CPC: 33533.180645161294
#
#
#  pCTR model: Dwane Model ,  basebid model: Elastic Net ,  Strategy 4
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 43819 | Clicks: 138 | Cost: 3330967 | CTR: 0.3149318788653324 | CPM: 0.07601649969191447 | CPC: 24137.442028985508
#
#
#  pCTR model: Dwane Model ,  basebid model: Random Forest Regressor ,  Strategy 1
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 75369 | Clicks: 142 | Cost: 6249963 | CTR: 0.18840637397338428 | CPM: 0.08292484973928273 | CPC: 44013.82394366197
#
#
#  pCTR model: Dwane Model ,  basebid model: Random Forest Regressor ,  Strategy 2
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 45617 | Clicks: 123 | Cost: 3039019 | CTR: 0.26963631979305963 | CPM: 0.06662031698708815 | CPC: 24707.47154471545
#
#
#  pCTR model: Dwane Model ,  basebid model: Random Forest Regressor ,  Strategy 3
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 59155 | Clicks: 155 | Cost: 5176612 | CTR: 0.2620234975910743 | CPM: 0.08750928915560814 | CPC: 33397.49677419355
#
#
#  pCTR model: Dwane Model ,  basebid model: Random Forest Regressor ,  Strategy 4
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 43944 | Clicks: 139 | Cost: 3411760 | CTR: 0.3163116693974149 | CPM: 0.07763881303477153 | CPC: 24545.03597122302
#
#
#  pCTR model: Dwane Model ,  basebid model: XGBoost Regressor ,  Strategy 1
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 75369 | Clicks: 142 | Cost: 6249963 | CTR: 0.18840637397338428 | CPM: 0.08292484973928273 | CPC: 44013.82394366197
#
#
#  pCTR model: Dwane Model ,  basebid model: XGBoost Regressor ,  Strategy 2
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 45823 | Clicks: 119 | Cost: 3085681 | CTR: 0.2596949130349388 | CPM: 0.06733913100408093 | CPC: 25930.092436974788
#
#
#  pCTR model: Dwane Model ,  basebid model: XGBoost Regressor ,  Strategy 3
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 59024 | Clicks: 155 | Cost: 5175335 | CTR: 0.26260504201680673 | CPM: 0.08768187516942261 | CPC: 33389.25806451613
#
#
#  pCTR model: Dwane Model ,  basebid model: XGBoost Regressor ,  Strategy 4
# Strategy statistics:
# Auctions participated: 303925 | Impressions: 43863 | Clicks: 135 | Cost: 3424937 | CTR: 0.30777648587647904 | CPM: 0.07808259808950596 | CPC: 25369.903703703705
#
#
# Total time: 32.90440787474314 mins

# %%
results
# Out:
#              pCTR_model            basebid_model   Strategy Impressions  \
# 0   Logistic Regression                    Lasso  Strategy1       79694
# 1   Logistic Regression                    Lasso  Strategy2      151952
# 2   Logistic Regression                    Lasso  Strategy3       83574
# 3   Logistic Regression                    Lasso  Strategy4      134072
# 4   Logistic Regression                    Ridge  Strategy1       79694
# 5   Logistic Regression                    Ridge  Strategy2      152217
# 6   Logistic Regression                    Ridge  Strategy3       83387
# 7   Logistic Regression                    Ridge  Strategy4      134674
# 8   Logistic Regression              Elastic Net  Strategy1       79694
# 9   Logistic Regression              Elastic Net  Strategy2      152014
# 10  Logistic Regression              Elastic Net  Strategy3       83218
# 11  Logistic Regression              Elastic Net  Strategy4      134730
# 12  Logistic Regression  Random Forest Regressor  Strategy1       79694
# 13  Logistic Regression  Random Forest Regressor  Strategy2      141252
# 14  Logistic Regression  Random Forest Regressor  Strategy3       83772
# 15  Logistic Regression  Random Forest Regressor  Strategy4      125239
# 16  Logistic Regression        XGBoost Regressor  Strategy1       79694
# 17  Logistic Regression        XGBoost Regressor  Strategy2      143838
# 18  Logistic Regression        XGBoost Regressor  Strategy3       83351
# 19  Logistic Regression        XGBoost Regressor  Strategy4      125916
# 20        Random Forest                    Lasso  Strategy1      110570
# 21        Random Forest                    Lasso  Strategy2       22537
# 22        Random Forest                    Lasso  Strategy3       11734
# 23        Random Forest                    Lasso  Strategy4        6407
# 24        Random Forest                    Ridge  Strategy1      110570
# 25        Random Forest                    Ridge  Strategy2       21241
# 26        Random Forest                    Ridge  Strategy3       11687
# 27        Random Forest                    Ridge  Strategy4        6463
# 28        Random Forest              Elastic Net  Strategy1      110570
# 29        Random Forest              Elastic Net  Strategy2       22074
# ..                  ...                      ...        ...         ...
# 50              XGBoost              Elastic Net  Strategy3        6866
# 51              XGBoost              Elastic Net  Strategy4        3833
# 52              XGBoost  Random Forest Regressor  Strategy1       92851
# 53              XGBoost  Random Forest Regressor  Strategy2        9224
# 54              XGBoost  Random Forest Regressor  Strategy3        6862
# 55              XGBoost  Random Forest Regressor  Strategy4        3750
# 56              XGBoost        XGBoost Regressor  Strategy1       92851
# 57              XGBoost        XGBoost Regressor  Strategy2        9267
# 58              XGBoost        XGBoost Regressor  Strategy3        6820
# 59              XGBoost        XGBoost Regressor  Strategy4        3724
# 60          Dwane Model                    Lasso  Strategy1       75369
# 61          Dwane Model                    Lasso  Strategy2       45524
# 62          Dwane Model                    Lasso  Strategy3       59182
# 63          Dwane Model                    Lasso  Strategy4       43622
# 64          Dwane Model                    Ridge  Strategy1       75369
# 65          Dwane Model                    Ridge  Strategy2       45746
# 66          Dwane Model                    Ridge  Strategy3       59200
# 67          Dwane Model                    Ridge  Strategy4       43911
# 68          Dwane Model              Elastic Net  Strategy1       75369
# 69          Dwane Model              Elastic Net  Strategy2       45503
# 70          Dwane Model              Elastic Net  Strategy3       59326
# 71          Dwane Model              Elastic Net  Strategy4       43819
# 72          Dwane Model  Random Forest Regressor  Strategy1       75369
# 73          Dwane Model  Random Forest Regressor  Strategy2       45617
# 74          Dwane Model  Random Forest Regressor  Strategy3       59155
# 75          Dwane Model  Random Forest Regressor  Strategy4       43944
# 76          Dwane Model        XGBoost Regressor  Strategy1       75369
# 77          Dwane Model        XGBoost Regressor  Strategy2       45823
# 78          Dwane Model        XGBoost Regressor  Strategy3       59024
# 79          Dwane Model        XGBoost Regressor  Strategy4       43863
#
#    Clicks     Cost       CTR       CPM            CPC
# 0      51  6249493  0.063995  0.078419  122539.078431
# 1     109  5901069  0.071733  0.038835   54138.247706
# 2      53  6249942  0.063417  0.074783  117923.433962
# 3     107  4821431  0.079808  0.035962   45060.102804
# 4      51  6249493  0.063995  0.078419  122539.078431
# 5     112  6083821  0.073579  0.039968   54319.830357
# 6      53  6249997  0.063559  0.074952  117924.471698
# 7     112  5074334  0.083164  0.037679   45306.553571
# 8      51  6249493  0.063995  0.078419  122539.078431
# 9     107  5919240  0.070388  0.038939   55320.000000
# 10     54  6249964  0.064890  0.075104  115740.074074
# 11    110  4918720  0.081645  0.036508   44715.636364
# 12     51  6249493  0.063995  0.078419  122539.078431
# 13    112  6018821  0.079291  0.042611   53739.473214
# 14     54  6249995  0.064461  0.074607  115740.648148
# 15    111  5047543  0.088631  0.040303   45473.360360
# 16     51  6249493  0.063995  0.078419  122539.078431
# 17    105  6249990  0.072999  0.043452   59523.714286
# 18     54  6249998  0.064786  0.074984  115740.703704
# 19    106  5119051  0.084183  0.040654   48292.933962
# 20     91  6249994  0.082301  0.056525   68681.252747
# 21     59   461519  0.261792  0.020478    7822.355932
# 22    103   899395  0.877791  0.076649    8731.990291
# 23     53   270423  0.827220  0.042207    5102.320755
# 24     91  6249994  0.082301  0.056525   68681.252747
# 25     66   465051  0.310720  0.021894    7046.227273
# 26    107   901150  0.915547  0.077107    8421.962617
# 27     59   287573  0.912889  0.044495    4874.118644
# 28     91  6249994  0.082301  0.056525   68681.252747
# 29     63   460390  0.285404  0.020857    7307.777778
# ..    ...      ...       ...       ...            ...
# 50     95   558988  1.383629  0.081414    5884.084211
# 51     87   196846  2.269763  0.051356    2262.597701
# 52    149  4504986  0.160472  0.048518   30234.805369
# 53     76   268707  0.823938  0.029131    3535.618421
# 54     96   558947  1.399009  0.081455    5822.364583
# 55     86   201628  2.293333  0.053767    2344.511628
# 56    149  4504986  0.160472  0.048518   30234.805369
# 57     76   270614  0.820114  0.029202    3560.710526
# 58     97   552807  1.422287  0.081057    5699.041237
# 59     84   200943  2.255639  0.053959    2392.178571
# 60    142  6249963  0.188406  0.082925   44013.823944
# 61    118  2749174  0.259204  0.060390   23298.084746
# 62    153  5161436  0.258525  0.087213   33734.875817
# 63    133  3262007  0.304892  0.074779   24526.368421
# 64    142  6249963  0.188406  0.082925   44013.823944
# 65    119  2904922  0.260132  0.063501   24411.109244
# 66    156  5182384  0.263514  0.087540   33220.410256
# 67    138  3374051  0.314272  0.076838   24449.644928
# 68    142  6249963  0.188406  0.082925   44013.823944
# 69    119  2810481  0.261521  0.061765   23617.487395
# 70    155  5197643  0.261268  0.087612   33533.180645
# 71    138  3330967  0.314932  0.076016   24137.442029
# 72    142  6249963  0.188406  0.082925   44013.823944
# 73    123  3039019  0.269636  0.066620   24707.471545
# 74    155  5176612  0.262023  0.087509   33397.496774
# 75    139  3411760  0.316312  0.077639   24545.035971
# 76    142  6249963  0.188406  0.082925   44013.823944
# 77    119  3085681  0.259695  0.067339   25930.092437
# 78    155  5175335  0.262605  0.087682   33389.258065
# 79    135  3424937  0.307776  0.078083   25369.903704
#
# [80 rows x 9 columns]

# %%
results.to_csv("ValidationSet_Eavaluation_Results.csv")

# %%
results.sort_values(by = "Clicks", ascending = False)
# Out:
#              pCTR_model            basebid_model   Strategy Impressions  \
# 66          Dwane Model                    Ridge  Strategy3       59200
# 78          Dwane Model        XGBoost Regressor  Strategy3       59024
# 74          Dwane Model  Random Forest Regressor  Strategy3       59155
# 70          Dwane Model              Elastic Net  Strategy3       59326
# 62          Dwane Model                    Lasso  Strategy3       59182
# 40              XGBoost                    Lasso  Strategy1       92851
# 44              XGBoost                    Ridge  Strategy1       92851
# 52              XGBoost  Random Forest Regressor  Strategy1       92851
# 56              XGBoost        XGBoost Regressor  Strategy1       92851
# 48              XGBoost              Elastic Net  Strategy1       92851
# 64          Dwane Model                    Ridge  Strategy1       75369
# 72          Dwane Model  Random Forest Regressor  Strategy1       75369
# 60          Dwane Model                    Lasso  Strategy1       75369
# 76          Dwane Model        XGBoost Regressor  Strategy1       75369
# 68          Dwane Model              Elastic Net  Strategy1       75369
# 75          Dwane Model  Random Forest Regressor  Strategy4       43944
# 67          Dwane Model                    Ridge  Strategy4       43911
# 71          Dwane Model              Elastic Net  Strategy4       43819
# 79          Dwane Model        XGBoost Regressor  Strategy4       43863
# 63          Dwane Model                    Lasso  Strategy4       43622
# 73          Dwane Model  Random Forest Regressor  Strategy2       45617
# 65          Dwane Model                    Ridge  Strategy2       45746
# 77          Dwane Model        XGBoost Regressor  Strategy2       45823
# 69          Dwane Model              Elastic Net  Strategy2       45503
# 61          Dwane Model                    Lasso  Strategy2       45524
# 5   Logistic Regression                    Ridge  Strategy2      152217
# 7   Logistic Regression                    Ridge  Strategy4      134674
# 13  Logistic Regression  Random Forest Regressor  Strategy2      141252
# 15  Logistic Regression  Random Forest Regressor  Strategy4      125239
# 11  Logistic Regression              Elastic Net  Strategy4      134730
# ..                  ...                      ...        ...         ...
# 51              XGBoost              Elastic Net  Strategy4        3833
# 55              XGBoost  Random Forest Regressor  Strategy4        3750
# 59              XGBoost        XGBoost Regressor  Strategy4        3724
# 47              XGBoost                    Ridge  Strategy4        3878
# 43              XGBoost                    Lasso  Strategy4        3735
# 45              XGBoost                    Ridge  Strategy2        9621
# 53              XGBoost  Random Forest Regressor  Strategy2        9224
# 57              XGBoost        XGBoost Regressor  Strategy2        9267
# 49              XGBoost              Elastic Net  Strategy2        9782
# 41              XGBoost                    Lasso  Strategy2        9735
# 25        Random Forest                    Ridge  Strategy2       21241
# 29        Random Forest              Elastic Net  Strategy2       22074
# 35        Random Forest  Random Forest Regressor  Strategy4        6406
# 33        Random Forest  Random Forest Regressor  Strategy2       20154
# 39        Random Forest        XGBoost Regressor  Strategy4        6344
# 21        Random Forest                    Lasso  Strategy2       22537
# 27        Random Forest                    Ridge  Strategy4        6463
# 37        Random Forest        XGBoost Regressor  Strategy2       20209
# 31        Random Forest              Elastic Net  Strategy4        6473
# 18  Logistic Regression        XGBoost Regressor  Strategy3       83351
# 10  Logistic Regression              Elastic Net  Strategy3       83218
# 14  Logistic Regression  Random Forest Regressor  Strategy3       83772
# 23        Random Forest                    Lasso  Strategy4        6407
# 2   Logistic Regression                    Lasso  Strategy3       83574
# 6   Logistic Regression                    Ridge  Strategy3       83387
# 16  Logistic Regression        XGBoost Regressor  Strategy1       79694
# 4   Logistic Regression                    Ridge  Strategy1       79694
# 8   Logistic Regression              Elastic Net  Strategy1       79694
# 12  Logistic Regression  Random Forest Regressor  Strategy1       79694
# 0   Logistic Regression                    Lasso  Strategy1       79694
#
#    Clicks     Cost       CTR       CPM            CPC
# 66    156  5182384  0.263514  0.087540   33220.410256
# 78    155  5175335  0.262605  0.087682   33389.258065
# 74    155  5176612  0.262023  0.087509   33397.496774
# 70    155  5197643  0.261268  0.087612   33533.180645
# 62    153  5161436  0.258525  0.087213   33734.875817
# 40    149  4504986  0.160472  0.048518   30234.805369
# 44    149  4504986  0.160472  0.048518   30234.805369
# 52    149  4504986  0.160472  0.048518   30234.805369
# 56    149  4504986  0.160472  0.048518   30234.805369
# 48    149  4504986  0.160472  0.048518   30234.805369
# 64    142  6249963  0.188406  0.082925   44013.823944
# 72    142  6249963  0.188406  0.082925   44013.823944
# 60    142  6249963  0.188406  0.082925   44013.823944
# 76    142  6249963  0.188406  0.082925   44013.823944
# 68    142  6249963  0.188406  0.082925   44013.823944
# 75    139  3411760  0.316312  0.077639   24545.035971
# 67    138  3374051  0.314272  0.076838   24449.644928
# 71    138  3330967  0.314932  0.076016   24137.442029
# 79    135  3424937  0.307776  0.078083   25369.903704
# 63    133  3262007  0.304892  0.074779   24526.368421
# 73    123  3039019  0.269636  0.066620   24707.471545
# 65    119  2904922  0.260132  0.063501   24411.109244
# 77    119  3085681  0.259695  0.067339   25930.092437
# 69    119  2810481  0.261521  0.061765   23617.487395
# 61    118  2749174  0.259204  0.060390   23298.084746
# 5     112  6083821  0.073579  0.039968   54319.830357
# 7     112  5074334  0.083164  0.037679   45306.553571
# 13    112  6018821  0.079291  0.042611   53739.473214
# 15    111  5047543  0.088631  0.040303   45473.360360
# 11    110  4918720  0.081645  0.036508   44715.636364
# ..    ...      ...       ...       ...            ...
# 51     87   196846  2.269763  0.051356    2262.597701
# 55     86   201628  2.293333  0.053767    2344.511628
# 59     84   200943  2.255639  0.053959    2392.178571
# 47     83   203459  2.140278  0.052465    2451.313253
# 43     82   187164  2.195448  0.050111    2282.487805
# 45     76   266765  0.789939  0.027727    3510.065789
# 53     76   268707  0.823938  0.029131    3535.618421
# 57     76   270614  0.820114  0.029202    3560.710526
# 49     75   254675  0.766714  0.026035    3395.666667
# 41     72   243507  0.739599  0.025014    3382.041667
# 25     66   465051  0.310720  0.021894    7046.227273
# 29     63   460390  0.285404  0.020857    7307.777778
# 35     61   294136  0.952232  0.045916    4821.901639
# 33     60   484209  0.297708  0.024025    8070.150000
# 39     59   291232  0.930013  0.045907    4936.135593
# 21     59   461519  0.261792  0.020478    7822.355932
# 27     59   287573  0.912889  0.044495    4874.118644
# 37     58   486322  0.287001  0.024065    8384.862069
# 31     56   279776  0.865132  0.043222    4996.000000
# 18     54  6249998  0.064786  0.074984  115740.703704
# 10     54  6249964  0.064890  0.075104  115740.074074
# 14     54  6249995  0.064461  0.074607  115740.648148
# 23     53   270423  0.827220  0.042207    5102.320755
# 2      53  6249942  0.063417  0.074783  117923.433962
# 6      53  6249997  0.063559  0.074952  117924.471698
# 16     51  6249493  0.063995  0.078419  122539.078431
# 4      51  6249493  0.063995  0.078419  122539.078431
# 8      51  6249493  0.063995  0.078419  122539.078431
# 12     51  6249493  0.063995  0.078419  122539.078431
# 0      51  6249493  0.063995  0.078419  122539.078431
#
# [80 rows x 9 columns]

# %%
from sklearn.metrics import mean_squared_error, make_scorer

# %%
def neg_rmse(y, y_pred):
    
    return -np.sqrt(mean_squared_error(y, y_pred))

basebid = train.loc[ train["click"] == 1, "payprice"].mean()
y_preds = list(basebid* np.ones(validation.shape[0]))
neg_rmse(validation["payprice"], y_preds)
# Out:
# -65.91350731270695
